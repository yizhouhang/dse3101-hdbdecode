# %%
import requests
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
from scipy.spatial import cKDTree
import os

# %%
df_resale = pd.read_csv('../data/raw/ResalePrice.csv')
df_resale['address'] = df_resale['block'] + ' ' + df_resale['street_name']

len(df_resale['address'].unique())
# Out:
# 9624

# %% [markdown]
# ### Get coordinates for each address

# %%
api_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..CMD124pML3xaJU45AklBASBYNmojp_wctKoRupiDkQ0"

# %%
df_resale
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 201055  2025-02      YISHUN  EXECUTIVE   364     YISHUN RING RD     01 TO 03
# 201056  2025-02      YISHUN  EXECUTIVE   328     YISHUN RING RD     01 TO 03
# 201057  2025-02      YISHUN  EXECUTIVE   723       YISHUN ST 71     07 TO 09
# 201058  2025-02      YISHUN  EXECUTIVE   824       YISHUN ST 81     01 TO 03
# 201059  2025-02      YISHUN  EXECUTIVE   826       YISHUN ST 81     10 TO 12
#
#         floor_area_sqm      flat_model  lease_commence_date  \
# 0                 44.0        Improved                 1979
# 1                 67.0  New Generation                 1978
# 2                 67.0  New Generation                 1980
# 3                 68.0  New Generation                 1980
# 4                 67.0  New Generation                 1980
# ...                ...             ...                  ...
# 201055           145.0      Maisonette                 1988
# 201056           142.0       Apartment                 1988
# 201057           146.0      Maisonette                 1986
# 201058           145.0       Apartment                 1987
# 201059           146.0      Maisonette                 1988
#
#            remaining_lease  resale_price                address latitude  \
# 0       61 years 04 months      232000.0  406 ANG MO KIO AVE 10     None
# 1       60 years 07 months      250000.0   108 ANG MO KIO AVE 4     None
# 2       62 years 05 months      262000.0   602 ANG MO KIO AVE 5     None
# 3        62 years 01 month      265000.0  465 ANG MO KIO AVE 10     None
# 4       62 years 05 months      265000.0   601 ANG MO KIO AVE 5     None
# ...                    ...           ...                    ...      ...
# 201055  62 years 03 months      860000.0     364 YISHUN RING RD     None
# 201056  62 years 05 months      845000.0     328 YISHUN RING RD     None
# 201057  60 years 05 months      818888.0       723 YISHUN ST 71     None
# 201058  61 years 10 months      868888.0       824 YISHUN ST 81     None
# 201059            62 years     1100888.0       826 YISHUN ST 81     None
#
#        longitude
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 201055      None
# 201056      None
# 201057      None
# 201058      None
# 201059      None
#
# [201060 rows x 14 columns]

# %%
def get_coordinates(address, token):
    url = "https://www.onemap.gov.sg/api/common/elastic/search"
    params = {'searchVal': address, 'returnGeom': 'Y', 'getAddrDetails': 'Y', 'pageNum': 1}
    headers = {'Authorization': token}

    try:
        response = requests.get(url, headers=headers, params=params).json()
        if response['found'] > 0:
            result = response['results'][0]
            return result['LATITUDE'], result['LONGITUDE']
    except requests.exceptions.RequestException:
        pass
    return None


df_resale['latitude'] = None
df_resale['longitude'] = None


unique_addresses = df_resale['address'].unique()
address_coords = {}

for address in unique_addresses:
    coords = get_coordinates(address, api_token)
    if coords:
        address_coords[address] = coords

df_resale['latitude'] = df_resale['address'].map(lambda x: address_coords.get(x, (None, None))[0]).astype(float)
df_resale['longitude'] = df_resale['address'].map(lambda x: address_coords.get(x, (None, None))[1]).astype(float)
# Out:
# {'SEARCHVAL': '406 ANG MO KIO AVENUE 10 SINGAPORE 560406', 'BLK_NO': '406', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'NIL', 'ADDRESS': '406 ANG MO KIO AVENUE 10 SINGAPORE 560406', 'POSTAL': '560406', 'X': '30288.2346631354', 'Y': '38229.0674628187', 'LATITUDE': '1.36200453938712', 'LONGITUDE': '103.853879910407'}
# {'SEARCHVAL': 'KEBUN BARU HEIGHTS', 'BLK_NO': '108', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'KEBUN BARU HEIGHTS', 'ADDRESS': '108 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560108', 'POSTAL': '560108', 'X': '28543.4587465767', 'Y': '39220.009892093', 'LATITUDE': '1.37096635222625', 'LONGITUDE': '103.838201940326'}
# {'SEARCHVAL': 'YIO CHU KANG GREEN', 'BLK_NO': '602', 'ROAD_NAME': 'ANG MO KIO AVENUE 5', 'BUILDING': 'YIO CHU KANG GREEN', 'ADDRESS': '602 ANG MO KIO AVENUE 5 YIO CHU KANG GREEN SINGAPORE 560602', 'POSTAL': '560602', 'X': '28228.0999537045', 'Y': '40297.2831488103', 'LATITUDE': '1.38070883044887', 'LONGITUDE': '103.835368226602'}
# {'SEARCHVAL': 'TECK GHEE HORIZON', 'BLK_NO': '465', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'TECK GHEE HORIZON', 'ADDRESS': '465 ANG MO KIO AVENUE 10 TECK GHEE HORIZON SINGAPORE 560465', 'POSTAL': '560465', 'X': '30657.8246932384', 'Y': '38693.0986568723', 'LATITUDE': '1.3662010408294', 'LONGITUDE': '103.857200967235'}
# {'SEARCHVAL': 'MY FIRST SKOOL', 'BLK_NO': '601', 'ROAD_NAME': 'ANG MO KIO AVENUE 5', 'BUILDING': 'MY FIRST SKOOL', 'ADDRESS': '601 ANG MO KIO AVENUE 5 MY FIRST SKOOL SINGAPORE 560601', 'POSTAL': '560601', 'X': '28201.7824866865', 'Y': '40334.0512122996', 'LATITUDE': '1.38104134784496', 'LONGITUDE': '103.835131744823'}
# {'SEARCHVAL': 'YIO CHU KANG GROVE', 'BLK_NO': '150', 'ROAD_NAME': 'ANG MO KIO AVENUE 5', 'BUILDING': 'YIO CHU KANG GROVE', 'ADDRESS': '150 ANG MO KIO AVENUE 5 YIO CHU KANG GROVE SINGAPORE 560150', 'POSTAL': '560150', 'X': '28968.1332683703', 'Y': '39865.8164612036', 'LATITUDE': '1.37680678506745', 'LONGITUDE': '103.842017962576'}
# {'SEARCHVAL': 'CHONG BOON CENTRE', 'BLK_NO': '447', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHONG BOON CENTRE', 'ADDRESS': '447 ANG MO KIO AVENUE 10 CHONG BOON CENTRE SINGAPORE 560447', 'POSTAL': '560447', 'X': '30520.5130165294', 'Y': '38834.4091277141', 'LATITUDE': '1.36747901420817', 'LONGITUDE': '103.855967139125'}
# {'SEARCHVAL': 'ANG MO KIO GROVE', 'BLK_NO': '218', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'ANG MO KIO GROVE', 'ADDRESS': '218 ANG MO KIO AVENUE 1 ANG MO KIO GROVE SINGAPORE 560218', 'POSTAL': '560218', 'X': '28937.4798521483', 'Y': '38573.4500436708', 'LATITUDE': '1.36511908595886', 'LONGITUDE': '103.841742478489'}
# {'SEARCHVAL': 'CHENG SAN COURT', 'BLK_NO': '571', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'CHENG SAN COURT', 'ADDRESS': '571 ANG MO KIO AVENUE 3 CHENG SAN COURT SINGAPORE 560571', 'POSTAL': '560571', 'X': '30399.5870944131', 'Y': '39119.2488639448', 'LATITUDE': '1.37005501296043', 'LONGITUDE': '103.85488055876'}
# {'SEARCHVAL': 'CHENG SAN VIEW', 'BLK_NO': '534', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHENG SAN VIEW', 'ADDRESS': '534 ANG MO KIO AVENUE 10 CHENG SAN VIEW SINGAPORE 560534', 'POSTAL': '560534', 'X': '30320.30304706', 'Y': '39561.9293249641', 'LATITUDE': '1.37405846295585', 'LONGITUDE': '103.854168170426'}
# {'SEARCHVAL': 'KEBUN BARU PALM VIEW', 'BLK_NO': '233', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'KEBUN BARU PALM VIEW', 'ADDRESS': '233 ANG MO KIO AVENUE 3 KEBUN BARU PALM VIEW SINGAPORE 560233', 'POSTAL': '560233', 'X': '28380.8330470454', 'Y': '38842.1638154108', 'LATITUDE': '1.36754924977907', 'LONGITUDE': '103.836740628478'}
# {'SEARCHVAL': 'KEBUN BARU PALM VIEW', 'BLK_NO': '235', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'KEBUN BARU PALM VIEW', 'ADDRESS': '235 ANG MO KIO AVENUE 3 KEBUN BARU PALM VIEW SINGAPORE 560235', 'POSTAL': '560235', 'X': '28353.0784864286', 'Y': '38761.9260844272', 'LATITUDE': '1.36682360872342', 'LONGITUDE': '103.83649123351'}
# {'SEARCHVAL': 'ANG MO KIO GROVE', 'BLK_NO': '219', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'ANG MO KIO GROVE', 'ADDRESS': '219 ANG MO KIO AVENUE 1 ANG MO KIO GROVE SINGAPORE 560219', 'POSTAL': '560219', 'X': '28816.3492579265', 'Y': '38668.8640811536', 'LATITUDE': '1.36598198004505', 'LONGITUDE': '103.840654039612'}
# {'SEARCHVAL': 'CHENG SAN VIEW', 'BLK_NO': '536', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHENG SAN VIEW', 'ADDRESS': '536 ANG MO KIO AVENUE 10 CHENG SAN VIEW SINGAPORE 560536', 'POSTAL': '560536', 'X': '30312.7735228948', 'Y': '39607.8534837943', 'LATITUDE': '1.37447378519738', 'LONGITUDE': '103.854100515826'}
# {'SEARCHVAL': 'KEBUN BARU PALM VIEW', 'BLK_NO': '230', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'KEBUN BARU PALM VIEW', 'ADDRESS': '230 ANG MO KIO AVENUE 3 KEBUN BARU PALM VIEW SINGAPORE 560230', 'POSTAL': '560230', 'X': '28509.4560266165', 'Y': '38986.4866770636', 'LATITUDE': '1.36885445228086', 'LONGITUDE': '103.837896397823'}
# {'SEARCHVAL': 'CHENG SAN COURT', 'BLK_NO': '570', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'CHENG SAN COURT', 'ADDRESS': '570 ANG MO KIO AVENUE 3 CHENG SAN COURT SINGAPORE 560570', 'POSTAL': '560570', 'X': '30526.7426821338', 'Y': '39084.8139777128', 'LATITUDE': '1.3697435855576', 'LONGITUDE': '103.856023138277'}
# {'SEARCHVAL': '624 ANG MO KIO AVENUE 4 SINGAPORE 560624', 'BLK_NO': '624', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'NIL', 'ADDRESS': '624 ANG MO KIO AVENUE 4 SINGAPORE 560624', 'POSTAL': '560624', 'X': '28743.8101280658', 'Y': '40391.5914363135', 'LATITUDE': '1.38156171229824', 'LONGITUDE': '103.84000226873'}
# {'SEARCHVAL': '441 ANG MO KIO AVENUE 10 SINGAPORE 560441', 'BLK_NO': '441', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'NIL', 'ADDRESS': '441 ANG MO KIO AVENUE 10 SINGAPORE 560441', 'POSTAL': '560441', 'X': '30320.3262626035', 'Y': '38676.4249629509', 'LATITUDE': '1.36605027829032', 'LONGITUDE': '103.854168309853'}
# {'SEARCHVAL': 'YIO CHU KANG HEIGHTS', 'BLK_NO': '625', 'ROAD_NAME': 'ANG MO KIO AVENUE 9', 'BUILDING': 'YIO CHU KANG HEIGHTS', 'ADDRESS': '625 ANG MO KIO AVENUE 9 YIO CHU KANG HEIGHTS SINGAPORE 560625', 'POSTAL': '560625', 'X': '28878.3857606538', 'Y': '40462.0242171884', 'LATITUDE': '1.38219867741921', 'LONGITUDE': '103.841211533475'}
# {'SEARCHVAL': '119 ANG MO KIO AVENUE 3 SINGAPORE 560119', 'BLK_NO': '119', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'NIL', 'ADDRESS': '119 ANG MO KIO AVENUE 3 SINGAPORE 560119', 'POSTAL': '560119', 'X': '29266.4932891754', 'Y': '39064.8857793771', 'LATITUDE': '1.36956344301912', 'LONGITUDE': '103.844698910817'}
# {'SEARCHVAL': 'KEBUN BARU VIEW', 'BLK_NO': '255', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'KEBUN BARU VIEW', 'ADDRESS': '255 ANG MO KIO AVENUE 4 KEBUN BARU VIEW SINGAPORE 560255', 'POSTAL': '560255', 'X': '28145.969263019', 'Y': '39185.5673480611', 'LATITUDE': '1.37065487078854', 'LONGITUDE': '103.834630215787'}
# {'SEARCHVAL': 'CHONG BOON RISE', 'BLK_NO': '432', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHONG BOON RISE', 'ADDRESS': '432 ANG MO KIO AVENUE 10 CHONG BOON RISE SINGAPORE 560432', 'POSTAL': '560432', 'X': '30257.1120628985', 'Y': '38926.289620243', 'LATITUDE': '1.36830996981351', 'LONGITUDE': '103.853600305664'}
# {'SEARCHVAL': '211 ANG MO KIO AVENUE 3 SINGAPORE 560211', 'BLK_NO': '211', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'NIL', 'ADDRESS': '211 ANG MO KIO AVENUE 3 SINGAPORE 560211', 'POSTAL': '560211', 'X': '28929.0379298814', 'Y': '39024.3611866981', 'LATITUDE': '1.369196965617', 'LONGITUDE': '103.841666636086'}
# {'SEARCHVAL': 'CHENG SAN COURT', 'BLK_NO': '584', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'CHENG SAN COURT', 'ADDRESS': '584 ANG MO KIO AVENUE 3 CHENG SAN COURT SINGAPORE 560584', 'POSTAL': '560584', 'X': '30245.7025161674', 'Y': '39192.0132178739', 'LATITUDE': '1.37071307985916', 'LONGITUDE': '103.853497803014'}
# {'SEARCHVAL': 'KEBUN BARU HEIGHTS', 'BLK_NO': '118', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'KEBUN BARU HEIGHTS', 'ADDRESS': '118 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560118', 'POSTAL': '560118', 'X': '28240.0632531969', 'Y': '39477.603025008', 'LATITUDE': '1.37329593649654', 'LONGITUDE': '103.835475719134'}
# {'SEARCHVAL': 'TECK GHEE VIEW', 'BLK_NO': '333', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'TECK GHEE VIEW', 'ADDRESS': '333 ANG MO KIO AVENUE 1 TECK GHEE VIEW SINGAPORE 560333', 'POSTAL': '560333', 'X': '30045.4833755', 'Y': '38155.8667959049', 'LATITUDE': '1.3613425564061', 'LONGITUDE': '103.851698621454'}
# {'SEARCHVAL': 'KEBUN BARU VIEW', 'BLK_NO': '256', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'KEBUN BARU VIEW', 'ADDRESS': '256 ANG MO KIO AVENUE 4 KEBUN BARU VIEW SINGAPORE 560256', 'POSTAL': '560256', 'X': '28294.8144035833', 'Y': '39181.178218009', 'LATITUDE': '1.37061517595951', 'LONGITUDE': '103.83596769452'}
# {'SEARCHVAL': 'TECK GHEE VIEW', 'BLK_NO': '330', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'TECK GHEE VIEW', 'ADDRESS': '330 ANG MO KIO AVENUE 1 TECK GHEE VIEW SINGAPORE 560330', 'POSTAL': '560330', 'X': '29971.1495055445', 'Y': '38276.3163302261', 'LATITUDE': '1.36243186402478', 'LONGITUDE': '103.851030689651'}
# {'SEARCHVAL': 'CHENG SAN PLACE', 'BLK_NO': '557', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHENG SAN PLACE', 'ADDRESS': '557 ANG MO KIO AVENUE 10 CHENG SAN PLACE SINGAPORE 560557', 'POSTAL': '560557', 'X': '30717.3733190438', 'Y': '39292.9307314958', 'LATITUDE': '1.3716257020332', 'LONGITUDE': '103.857736107527'}
# {'SEARCHVAL': 'ANG MO KIO 31', 'BLK_NO': '302', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'ANG MO KIO 31', 'ADDRESS': '302 ANG MO KIO AVENUE 3 ANG MO KIO 31 SINGAPORE 560302', 'POSTAL': '560302', 'X': '29373.4744485123', 'Y': '38791.3669652212', 'LATITUDE': '1.36708983179046', 'LONGITUDE': '103.845660199054'}
# {'SEARCHVAL': 'CHENG SAN COURT', 'BLK_NO': '575', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHENG SAN COURT', 'ADDRESS': '575 ANG MO KIO AVENUE 10 CHENG SAN COURT SINGAPORE 560575', 'POSTAL': '560575', 'X': '30518.9740106286', 'Y': '39266.7057937048', 'LATITUDE': '1.37138855070768', 'LONGITUDE': '103.855953346739'}
# {'SEARCHVAL': 'CHENG SAN CREST', 'BLK_NO': '509', 'ROAD_NAME': 'ANG MO KIO AVENUE 8', 'BUILDING': 'CHENG SAN CREST', 'ADDRESS': '509 ANG MO KIO AVENUE 8 CHENG SAN CREST SINGAPORE 560509', 'POSTAL': '560509', 'X': '29871.9957073322', 'Y': '39555.5569155477', 'LATITUDE': '1.37400086510074', 'LONGITUDE': '103.850139806283'}
# {'SEARCHVAL': 'TECK GHEE HORIZON', 'BLK_NO': '472', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'TECK GHEE HORIZON', 'ADDRESS': '472 ANG MO KIO AVENUE 10 TECK GHEE HORIZON SINGAPORE 560472', 'POSTAL': '560472', 'X': '30759.9490216402', 'Y': '38355.059549246', 'LATITUDE': '1.36314392666998', 'LONGITUDE': '103.858118593427'}
# {'SEARCHVAL': 'TECK GHEE HORIZON', 'BLK_NO': '475', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'TECK GHEE HORIZON', 'ADDRESS': '475 ANG MO KIO AVENUE 10 TECK GHEE HORIZON SINGAPORE 560475', 'POSTAL': '560475', 'X': '30581.5912348917', 'Y': '38301.8769463114', 'LATITUDE': '1.36266297827625', 'LONGITUDE': '103.85651592319'}
# {'SEARCHVAL': 'YIO CHU KANG VIEW', 'BLK_NO': '629', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'YIO CHU KANG VIEW', 'ADDRESS': '629 ANG MO KIO AVENUE 4 YIO CHU KANG VIEW SINGAPORE 560629', 'POSTAL': '560629', 'X': '28789.0360347796', 'Y': '40230.488065023', 'LATITUDE': '1.380104749906', 'LONGITUDE': '103.840408652998'}
# {'SEARCHVAL': 'CHENG SAN GREEN', 'BLK_NO': '546', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'CHENG SAN GREEN', 'ADDRESS': '546 ANG MO KIO AVENUE 10 CHENG SAN GREEN SINGAPORE 560546', 'POSTAL': '560546', 'X': '30637.9241598397', 'Y': '39516.9034896214', 'LATITUDE': '1.37365123866689', 'LONGITUDE': '103.857022220393'}
# {'SEARCHVAL': 'YIO CHU KANG VILLE', 'BLK_NO': '131', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'YIO CHU KANG VILLE', 'ADDRESS': '131 ANG MO KIO AVENUE 3 YIO CHU KANG VILLE SINGAPORE 560131', 'POSTAL': '560131', 'X': '28943.9150373628', 'Y': '39225.4304642249', 'LATITUDE': '1.37101536386003', 'LONGITUDE': '103.841800323712'}
# {'SEARCHVAL': 'KEBUN BARU VIEW', 'BLK_NO': '254', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'KEBUN BARU VIEW', 'ADDRESS': '254 ANG MO KIO AVENUE 4 KEBUN BARU VIEW SINGAPORE 560254', 'POSTAL': '560254', 'X': '28152.3690952277', 'Y': '39135.6504789609', 'LATITUDE': '1.37020344042146', 'LONGITUDE': '103.834687722549'}
# {'SEARCHVAL': 'LITTLE GENIUS EDUCARE CENTRE', 'BLK_NO': '470', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'LITTLE GENIUS EDUCARE CENTRE', 'ADDRESS': '470 ANG MO KIO AVENUE 10 LITTLE GENIUS EDUCARE CENTRE SINGAPORE 560470', 'POSTAL': '560470', 'X': '30601.2304950552', 'Y': '38459.2497886084', 'LATITUDE': '1.36408620030202', 'LONGITUDE': '103.856692408941'}
# {'SEARCHVAL': '463 ANG MO KIO AVENUE 10 SINGAPORE 560463', 'BLK_NO': '463', 'ROAD_NAME': 'ANG MO KIO AVENUE 10', 'BUILDING': 'NIL', 'ADDRESS': '463 ANG MO KIO AVENUE 10 SINGAPORE 560463', 'POSTAL': '560463', 'X': '30689.7280863831', 'Y': '38775.686757328', 'LATITUDE': '1.36694793518613', 'LONGITUDE': '103.857487648675'}
# {'SEARCHVAL': 'ANG MO KIO 22', 'BLK_NO': '207', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'ANG MO KIO 22', 'ADDRESS': '207 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPORE 560207', 'POSTAL': '560207', 'X': '29060.4855782297', 'Y': '38651.0529769398', 'LATITUDE': '1.36582089504381', 'LONGITUDE': '103.842847772078'}
# {'SEARCHVAL': 'TECK GHEE VISTA', 'BLK_NO': '304', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'TECK GHEE VISTA', 'ADDRESS': '304 ANG MO KIO AVENUE 1 TECK GHEE VISTA SINGAPORE 560304', 'POSTAL': '560304', 'X': '29299.4196190983', 'Y': '38702.5303119384', 'LATITUDE': '1.36628642816469', 'LONGITUDE': '103.8449947612'}
# {'SEARCHVAL': 'ANG MO KIO 61', 'BLK_NO': '646', 'ROAD_NAME': 'ANG MO KIO AVENUE 6', 'BUILDING': 'ANG MO KIO 61', 'ADDRESS': '646 ANG MO KIO AVENUE 6 ANG MO KIO 61 SINGAPORE 560646', 'POSTAL': '560646', 'X': '29162.399695484', 'Y': '40152.028457012', 'LATITUDE': '1.37939517687868', 'LONGITUDE': '103.843763599411'}
# {'SEARCHVAL': 'ANG MO KIO 31', 'BLK_NO': '328', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'ANG MO KIO 31', 'ADDRESS': '328 ANG MO KIO AVENUE 3 ANG MO KIO 31 SINGAPORE 560328', 'POSTAL': '560328', 'X': '29619.0524934148', 'Y': '38739.1886237189', 'LATITUDE': '1.36661793708764', 'LONGITUDE': '103.84786688518'}
# {'SEARCHVAL': 'PARK CENTRAL @ AMK', 'BLK_NO': '588C', 'ROAD_NAME': 'ANG MO KIO STREET 52', 'BUILDING': 'PARK CENTRAL @ AMK', 'ADDRESS': '588C ANG MO KIO STREET 52 PARK CENTRAL @ AMK SINGAPORE 563588', 'POSTAL': '563588', 'X': '30264.9737479165', 'Y': '39315.6903483681', 'LATITUDE': '1.37183157010083', 'LONGITUDE': '103.853670978083'}
# {'SEARCHVAL': 'PARK CENTRAL @ AMK', 'BLK_NO': '588D', 'ROAD_NAME': 'ANG MO KIO STREET 52', 'BUILDING': 'PARK CENTRAL @ AMK', 'ADDRESS': '588D ANG MO KIO STREET 52 PARK CENTRAL @ AMK SINGAPORE 564588', 'POSTAL': '564588', 'X': '30288.6036298573', 'Y': '39307.1139757186', 'LATITUDE': '1.37175400663025', 'LONGITUDE': '103.8538833087'}
# {'SEARCHVAL': 'KEBUN BARU HEIGHTS', 'BLK_NO': '101', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'KEBUN BARU HEIGHTS', 'ADDRESS': '101 ANG MO KIO AVENUE 3 KEBUN BARU HEIGHTS SINGAPORE 560101', 'POSTAL': '560101', 'X': '28684.3447392145', 'Y': '39142.0805186182', 'LATITUDE': '1.37026158388486', 'LONGITUDE': '103.839467898898'}
# {'SEARCHVAL': 'CHONG BOON HEIGHTS', 'BLK_NO': '430', 'ROAD_NAME': 'ANG MO KIO AVENUE 3', 'BUILDING': 'CHONG BOON HEIGHTS', 'ADDRESS': '430 ANG MO KIO AVENUE 3 CHONG BOON HEIGHTS SINGAPORE 560430', 'POSTAL': '560430', 'X': '30163.7457453171', 'Y': '39001.801338518', 'LATITUDE': '1.36899287777802', 'LONGITUDE': '103.85276134968'}
# {'SEARCHVAL': '520 ANG MO KIO AVENUE 5 SINGAPORE 560520', 'BLK_NO': '520', 'ROAD_NAME': 'ANG MO KIO AVENUE 5', 'BUILDING': 'NIL', 'ADDRESS': '520 ANG MO KIO AVENUE 5 SINGAPORE 560520', 'POSTAL': '560520', 'X': '29982.6621752949', 'Y': '39489.7149100322', 'LATITUDE': '1.3734054063175', 'LONGITUDE': '103.851134219635'}
# {'SEARCHVAL': '716 ANG MO KIO AVENUE 6 SINGAPORE 560716', 'BLK_NO': '716', 'ROAD_NAME': 'ANG MO KIO AVENUE 6', 'BUILDING': 'NIL', 'ADDRESS': '716 ANG MO KIO AVENUE 6 SINGAPORE 560716', 'POSTAL': '560716', 'X': '29396.6812445764', 'Y': '39276.5696755778', 'LATITUDE': '1.37147783065153', 'LONGITUDE': '103.845868750998'}
# {'SEARCHVAL': 'PARK CENTRAL @ AMK', 'BLK_NO': '588A', 'ROAD_NAME': 'ANG MO KIO STREET 52', 'BUILDING': 'PARK CENTRAL @ AMK', 'ADDRESS': '588A ANG MO KIO STREET 52 PARK CENTRAL @ AMK SINGAPORE 561588', 'POSTAL': '561588', 'X': '30166.5017663063', 'Y': '39342.8156073373', 'LATITUDE': '1.37207688864036', 'LONGITUDE': '103.852786139342'}
# {'SEARCHVAL': 'PCF SPARKLETOTS PRESCHOOL @ TECK GHEE 310A (CC)', 'BLK_NO': '310A', 'ROAD_NAME': 'ANG MO KIO AVENUE 1', 'BUILDING': 'PCF SPARKLETOTS PRESCHOOL @ TECK GHEE 310A (CC)', 'ADDRESS': '310A ANG MO KIO AVENUE 1 PCF SPARKLETOTS PRESCHOOL @ TECK GHEE 310A (CC) SINGAPORE 561310', 'POSTAL': '561310', 'X': '29171.3815077767', 'Y': '38539.5559857711', 'LATITUDE': '1.36481255187585', 'LONGITUDE': '103.843844243986'}
# {'SEARCHVAL': '613 ANG MO KIO AVENUE 4 SINGAPORE 560613', 'BLK_NO': '613', 'ROAD_NAME': 'ANG MO KIO AVENUE 4', 'BUILDING': 'NIL', 'ADDRESS': '613 ANG MO KIO AVENUE 4 SINGAPORE 560613', 'POSTAL': '560613', 'X': '28664.8466186598', 'Y': '40048.245412834', 'LATITUDE': '1.37845661566039', 'LONGITUDE': '103.839292714848'}
# {'SEARCHVAL': 'PEARL GARDEN', 'BLK_NO': '101', 'ROAD_NAME': 'BEDOK NORTH AVENUE 4', 'BUILDING': 'PEARL GARDEN', 'ADDRESS': '101 BEDOK NORTH AVENUE 4 PEARL GARDEN SINGAPORE 460101', 'POSTAL': '460101', 'X': '39641.5706253285', 'Y': '35186.2982802857', 'LATITUDE': '1.334484667124', 'LONGITUDE': '103.937924710969'}
# {'SEARCHVAL': '548 BEDOK NORTH AVENUE 1 SINGAPORE 460548', 'BLK_NO': '548', 'ROAD_NAME': 'BEDOK NORTH AVENUE 1', 'BUILDING': 'NIL', 'ADDRESS': '548 BEDOK NORTH AVENUE 1 SINGAPORE 460548', 'POSTAL': '460548', 'X': '38409.5189768048', 'Y': '34835.2339209579', 'LATITUDE': '1.33131021834565', 'LONGITUDE': '103.92685391703'}
# {'SEARCHVAL': '75 BEDOK NORTH ROAD SINGAPORE 460075', 'BLK_NO': '75', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '75 BEDOK NORTH ROAD SINGAPORE 460075', 'POSTAL': '460075', 'X': '40111.2135943677', 'Y': '34459.8528083339', 'LATITUDE': '1.32791477933184', 'LONGITUDE': '103.942144427101'}
# {'SEARCHVAL': '550 BEDOK NORTH AVENUE 1 SINGAPORE 460550', 'BLK_NO': '550', 'ROAD_NAME': 'BEDOK NORTH AVENUE 1', 'BUILDING': 'NIL', 'ADDRESS': '550 BEDOK NORTH AVENUE 1 SINGAPORE 460550', 'POSTAL': '460550', 'X': '38383.1915818881', 'Y': '34988.1538888309', 'LATITUDE': '1.3326931795279', 'LONGITUDE': '103.926617402908'}
# {'SEARCHVAL': '1 BEDOK SOUTH AVENUE 1 SINGAPORE 460001', 'BLK_NO': '1', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 1', 'BUILDING': 'NIL', 'ADDRESS': '1 BEDOK SOUTH AVENUE 1 SINGAPORE 460001', 'POSTAL': '460001', 'X': '39173.8123528324', 'Y': '33678.8556520101', 'LATITUDE': '1.32085208689731', 'LONGITUDE': '103.933721091441'}
# {'SEARCHVAL': 'EUNOS SPRING', 'BLK_NO': '151', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS SPRING', 'ADDRESS': '151 BEDOK RESERVOIR ROAD EUNOS SPRING SINGAPORE 470151', 'POSTAL': '470151', 'X': '36705.8649310488', 'Y': '35306.884837769', 'LATITUDE': '1.33557619454702', 'LONGITUDE': '103.911545779692'}
# {'SEARCHVAL': 'CHAI CHEE GARDENS', 'BLK_NO': '54', 'ROAD_NAME': 'CHAI CHEE STREET', 'BUILDING': 'CHAI CHEE GARDENS', 'ADDRESS': '54 CHAI CHEE STREET CHAI CHEE GARDENS SINGAPORE 460054', 'POSTAL': '460054', 'X': '37769.742909966', 'Y': '34632.6580545418', 'LATITUDE': '1.32947840879761', 'LONGITUDE': '103.921105111921'}
# {'SEARCHVAL': 'CHAI CHEE GARDENS', 'BLK_NO': '50', 'ROAD_NAME': 'CHAI CHEE STREET', 'BUILDING': 'CHAI CHEE GARDENS', 'ADDRESS': '50 CHAI CHEE STREET CHAI CHEE GARDENS SINGAPORE 461050', 'POSTAL': '461050', 'X': '37915.6107100435', 'Y': '34613.4127624556', 'LATITUDE': '1.32930431416537', 'LONGITUDE': '103.922415807329'}
# {'SEARCHVAL': 'EUNOS VISTA', 'BLK_NO': '105', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS VISTA', 'ADDRESS': '105 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470105', 'POSTAL': '470105', 'X': '36435.1194209009', 'Y': '34595.6785691865', 'LATITUDE': '1.32914437941094', 'LONGITUDE': '103.909112780576'}
# {'SEARCHVAL': '528 BEDOK NORTH STREET 3 SINGAPORE 460528', 'BLK_NO': '528', 'ROAD_NAME': 'BEDOK NORTH STREET 3', 'BUILDING': 'NIL', 'ADDRESS': '528 BEDOK NORTH STREET 3 SINGAPORE 460528', 'POSTAL': '460528', 'X': '38519.0407398911', 'Y': '35232.496303834', 'LATITUDE': '1.33490287587397', 'LONGITUDE': '103.927838167286'}
# {'SEARCHVAL': '534 BEDOK NORTH STREET 3 SINGAPORE 460534', 'BLK_NO': '534', 'ROAD_NAME': 'BEDOK NORTH STREET 3', 'BUILDING': 'NIL', 'ADDRESS': '534 BEDOK NORTH STREET 3 SINGAPORE 460534', 'POSTAL': '460534', 'X': '38182.2950134762', 'Y': '35026.1623342913', 'LATITUDE': '1.33303698213001', 'LONGITUDE': '103.924812248346'}
# {'SEARCHVAL': '77 BEDOK NORTH ROAD SINGAPORE 460077', 'BLK_NO': '77', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '77 BEDOK NORTH ROAD SINGAPORE 460077', 'POSTAL': '460077', 'X': '40094.6467766957', 'Y': '34546.2479552459', 'LATITUDE': '1.32869611162886', 'LONGITUDE': '103.941995599533'}
# {'SEARCHVAL': 'EUNOS VISTA', 'BLK_NO': '116', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS VISTA', 'ADDRESS': '116 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470116', 'POSTAL': '470116', 'X': '36382.6792916069', 'Y': '34805.0469646323', 'LATITUDE': '1.33103784588692', 'LONGITUDE': '103.908641634756'}
# {'SEARCHVAL': '18 BEDOK SOUTH ROAD SINGAPORE 460018', 'BLK_NO': '18', 'ROAD_NAME': 'BEDOK SOUTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '18 BEDOK SOUTH ROAD SINGAPORE 460018', 'POSTAL': '460018', 'X': '39286.5650113048', 'Y': '33653.7554724924', 'LATITUDE': '1.32062504871279', 'LONGITUDE': '103.934734222428'}
# {'SEARCHVAL': 'ANSAR GARDEN', 'BLK_NO': '40', 'ROAD_NAME': 'CHAI CHEE AVENUE', 'BUILDING': 'ANSAR GARDEN', 'ADDRESS': '40 CHAI CHEE AVENUE ANSAR GARDEN SINGAPORE 461040', 'POSTAL': '461040', 'X': '38368.8684087768', 'Y': '34252.8486450966', 'LATITUDE': '1.32604335303082', 'LONGITUDE': '103.926488452026'}
# {'SEARCHVAL': '57 NEW UPPER CHANGI ROAD SINGAPORE 461057', 'BLK_NO': '57', 'ROAD_NAME': 'NEW UPPER CHANGI ROAD', 'BUILDING': 'NIL', 'ADDRESS': '57 NEW UPPER CHANGI ROAD SINGAPORE 461057', 'POSTAL': '461057', 'X': '40047.159125166', 'Y': '34054.1237742491', 'LATITUDE': '1.32424554153984', 'LONGITUDE': '103.941568704132'}
# {'SEARCHVAL': 'PEARL GARDEN', 'BLK_NO': '105', 'ROAD_NAME': 'BEDOK NORTH AVENUE 4', 'BUILDING': 'PEARL GARDEN', 'ADDRESS': '105 BEDOK NORTH AVENUE 4 PEARL GARDEN SINGAPORE 460105', 'POSTAL': '460105', 'X': '39484.9904712569', 'Y': '35102.049193956', 'LATITUDE': '1.33372280929', 'LONGITUDE': '103.936517719048'}
# {'SEARCHVAL': 'BEDOK RESERVOIR GARDEN', 'BLK_NO': '709', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'BEDOK RESERVOIR GARDEN', 'ADDRESS': '709 BEDOK RESERVOIR ROAD BEDOK RESERVOIR GARDEN SINGAPORE 470709', 'POSTAL': '470709', 'X': '37908.2703607762', 'Y': '35289.2195646986', 'LATITUDE': '1.33541606639526', 'LONGITUDE': '103.922350069667'}
# {'SEARCHVAL': 'PING YI GARDENS', 'BLK_NO': '42', 'ROAD_NAME': 'CHAI CHEE STREET', 'BUILDING': 'PING YI GARDENS', 'ADDRESS': '42 CHAI CHEE STREET PING YI GARDENS SINGAPORE 461042', 'POSTAL': '461042', 'X': '38292.775938699', 'Y': '34466.8549431525', 'LATITUDE': '1.32797877350561', 'LONGITUDE': '103.925804792632'}
# {'SEARCHVAL': 'PING-AN GARDENS', 'BLK_NO': '55', 'ROAD_NAME': 'CHAI CHEE DRIVE', 'BUILDING': 'PING-AN GARDENS', 'ADDRESS': '55 CHAI CHEE DRIVE PING-AN GARDENS SINGAPORE 460055', 'POSTAL': '460055', 'X': '37537.2085196981', 'Y': '34341.8443566337', 'LATITUDE': '1.32684846948333', 'LONGITUDE': '103.919015573079'}
# {'SEARCHVAL': '2 BEDOK SOUTH AVENUE 1 SINGAPORE 460002', 'BLK_NO': '2', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 1', 'BUILDING': 'NIL', 'ADDRESS': '2 BEDOK SOUTH AVENUE 1 SINGAPORE 460002', 'POSTAL': '460002', 'X': '39126.8995811166', 'Y': '33728.5131244883', 'LATITUDE': '1.32130118793544', 'LONGITUDE': '103.933299574181'}
# {'SEARCHVAL': 'ANSAR GARDEN', 'BLK_NO': '37', 'ROAD_NAME': 'CHAI CHEE AVENUE', 'BUILDING': 'ANSAR GARDEN', 'ADDRESS': '37 CHAI CHEE AVENUE ANSAR GARDEN SINGAPORE 461037', 'POSTAL': '461037', 'X': '38337.6186830075', 'Y': '34186.3532446157', 'LATITUDE': '1.32544200357037', 'LONGITUDE': '103.926207634232'}
# {'SEARCHVAL': 'GARDEN HILL', 'BLK_NO': '425', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'GARDEN HILL', 'ADDRESS': '425 BEDOK NORTH ROAD GARDEN HILL SINGAPORE 460425', 'POSTAL': '460425', 'X': '38655.8805387346', 'Y': '34620.6596139204', 'LATITUDE': '1.32936960154503', 'LONGITUDE': '103.929067536324'}
# {'SEARCHVAL': '117 BEDOK NORTH ROAD SINGAPORE 460117', 'BLK_NO': '117', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '117 BEDOK NORTH ROAD SINGAPORE 460117', 'POSTAL': '460117', 'X': '39705.1979527446', 'Y': '34762.7852923684', 'LATITUDE': '1.33065454769523', 'LONGITUDE': '103.938496275607'}
# {'SEARCHVAL': 'GARDEN HILL', 'BLK_NO': '423', 'ROAD_NAME': 'BEDOK NORTH AVENUE 1', 'BUILDING': 'GARDEN HILL', 'ADDRESS': '423 BEDOK NORTH AVENUE 1 GARDEN HILL SINGAPORE 460423', 'POSTAL': '460423', 'X': '38488.6816495433', 'Y': '34466.5712716077', 'LATITUDE': '1.32797614118511', 'LONGITUDE': '103.927565110763'}
# {'SEARCHVAL': '533 BEDOK NORTH STREET 3 SINGAPORE 460533', 'BLK_NO': '533', 'ROAD_NAME': 'BEDOK NORTH STREET 3', 'BUILDING': 'NIL', 'ADDRESS': '533 BEDOK NORTH STREET 3 SINGAPORE 460533', 'POSTAL': '460533', 'X': '38116.2332926663', 'Y': '35086.2220652699', 'LATITUDE': '1.33358016248275', 'LONGITUDE': '103.92421866691'}
# {'SEARCHVAL': 'EUNOS SPRING', 'BLK_NO': '149', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS SPRING', 'ADDRESS': '149 BEDOK RESERVOIR ROAD EUNOS SPRING SINGAPORE 470149', 'POSTAL': '470149', 'X': '36843.1755786464', 'Y': '35328.241654668', 'LATITUDE': '1.33576929801793', 'LONGITUDE': '103.912779600202'}
# {'SEARCHVAL': 'BEDOK SOUTH PARKVIEW', 'BLK_NO': '35', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 2', 'BUILDING': 'BEDOK SOUTH PARKVIEW', 'ADDRESS': '35 BEDOK SOUTH AVENUE 2 BEDOK SOUTH PARKVIEW SINGAPORE 460035', 'POSTAL': '460035', 'X': '39846.5693833055', 'Y': '33842.548055822', 'LATITUDE': '1.32233220742919', 'LONGITUDE': '103.939766219283'}
# {'SEARCHVAL': 'BEDOK SOUTH PARKVIEW', 'BLK_NO': '42', 'ROAD_NAME': 'BEDOK SOUTH ROAD', 'BUILDING': 'BEDOK SOUTH PARKVIEW', 'ADDRESS': '42 BEDOK SOUTH ROAD BEDOK SOUTH PARKVIEW SINGAPORE 460042', 'POSTAL': '460042', 'X': '39952.8364603706', 'Y': '33748.1514766123', 'LATITUDE': '1.32147847826862', 'LONGITUDE': '103.940721046918'}
# {'SEARCHVAL': 'BEDOK SOUTH PARKVIEW', 'BLK_NO': '34', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 2', 'BUILDING': 'BEDOK SOUTH PARKVIEW', 'ADDRESS': '34 BEDOK SOUTH AVENUE 2 BEDOK SOUTH PARKVIEW SINGAPORE 460034', 'POSTAL': '460034', 'X': '39689.4853278408', 'Y': '33812.0582380537', 'LATITUDE': '1.32205652925918', 'LONGITUDE': '103.93835472666'}
# {'SEARCHVAL': '7 BEDOK SOUTH AVENUE 2 SINGAPORE 460007', 'BLK_NO': '7', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 2', 'BUILDING': 'NIL', 'ADDRESS': '7 BEDOK SOUTH AVENUE 2 SINGAPORE 460007', 'POSTAL': '460007', 'X': '39366.7977480711', 'Y': '33895.961664008', 'LATITUDE': '1.32281544267372', 'LONGITUDE': '103.93545524391'}
# {'SEARCHVAL': '8 BEDOK SOUTH AVENUE 2 SINGAPORE 460008', 'BLK_NO': '8', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 2', 'BUILDING': 'NIL', 'ADDRESS': '8 BEDOK SOUTH AVENUE 2 SINGAPORE 460008', 'POSTAL': '460008', 'X': '39432.6336999908', 'Y': '33898.875502266', 'LATITUDE': '1.32284176978435', 'LONGITUDE': '103.936046815062'}
# {'SEARCHVAL': '80 BEDOK NORTH ROAD SINGAPORE 460080', 'BLK_NO': '80', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '80 BEDOK NORTH ROAD SINGAPORE 460080', 'POSTAL': '460080', 'X': '39940.6235408168', 'Y': '34522.4906450938', 'LATITUDE': '1.32848132017235', 'LONGITUDE': '103.940611608837'}
# {'SEARCHVAL': '78 BEDOK NORTH ROAD SINGAPORE 460078', 'BLK_NO': '78', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '78 BEDOK NORTH ROAD SINGAPORE 460078', 'POSTAL': '460078', 'X': '39967.0230946066', 'Y': '34387.4522150345', 'LATITUDE': '1.32726007220341', 'LONGITUDE': '103.940848770214'}
# {'SEARCHVAL': 'EUNOS SPRING', 'BLK_NO': '135', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS SPRING', 'ADDRESS': '135 BEDOK RESERVOIR ROAD EUNOS SPRING SINGAPORE 470135', 'POSTAL': '470135', 'X': '36814.6878971951', 'Y': '35037.6238208823', 'LATITUDE': '1.33314106418951', 'LONGITUDE': '103.912523538101'}
# {'SEARCHVAL': 'EUNOS SPRING', 'BLK_NO': '148', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS SPRING', 'ADDRESS': '148 BEDOK RESERVOIR ROAD EUNOS SPRING SINGAPORE 470148', 'POSTAL': '470148', 'X': '36745.8417942952', 'Y': '35280.8667211086', 'LATITUDE': '1.33534088461813', 'LONGITUDE': '103.91190498709'}
# {'SEARCHVAL': '81 BEDOK NORTH ROAD SINGAPORE 460081', 'BLK_NO': '81', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '81 BEDOK NORTH ROAD SINGAPORE 460081', 'POSTAL': '460081', 'X': '39931.3977383077', 'Y': '34570.5088035744', 'LATITUDE': '1.32891558225172', 'LONGITUDE': '103.940528728774'}
# {'SEARCHVAL': 'EUNOS SPRING', 'BLK_NO': '142', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS SPRING', 'ADDRESS': '142 BEDOK RESERVOIR ROAD EUNOS SPRING SINGAPORE 470142', 'POSTAL': '470142', 'X': '36897.6809832724', 'Y': '35313.5590189826', 'LATITUDE': '1.33563649761465', 'LONGITUDE': '103.913269358016'}
# {'SEARCHVAL': '124 BEDOK NORTH ROAD SINGAPORE 460124', 'BLK_NO': '124', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'NIL', 'ADDRESS': '124 BEDOK NORTH ROAD SINGAPORE 460124', 'POSTAL': '460124', 'X': '39766.4312037202', 'Y': '34608.4551694021', 'LATITUDE': '1.32925881944574', 'LONGITUDE': '103.939046430321'}
# {'SEARCHVAL': 'RESERVOIR RISE', 'BLK_NO': '705', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'RESERVOIR RISE', 'ADDRESS': '705 BEDOK NORTH ROAD RESERVOIR RISE SINGAPORE 470705', 'POSTAL': '470705', 'X': '37534.9097874062', 'Y': '35424.190920908', 'LATITUDE': '1.33663681806047', 'LONGITUDE': '103.918995255673'}
# {'SEARCHVAL': 'KAKI BUKIT GREEN', 'BLK_NO': '554', 'ROAD_NAME': 'BEDOK NORTH STREET 3', 'BUILDING': 'KAKI BUKIT GREEN', 'ADDRESS': '554 BEDOK NORTH STREET 3 KAKI BUKIT GREEN SINGAPORE 460554', 'POSTAL': '460554', 'X': '38556.2160893688', 'Y': '34980.859335022', 'LATITUDE': '1.33262715051315', 'LONGITUDE': '103.928172121608'}
# {'SEARCHVAL': 'EUNOS RAINBOW', 'BLK_NO': '602', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS RAINBOW', 'ADDRESS': '602 BEDOK RESERVOIR ROAD EUNOS RAINBOW SINGAPORE 470602', 'POSTAL': '470602', 'X': '36710.0554123223', 'Y': '34618.311605351', 'LATITUDE': '1.32934898685946', 'LONGITUDE': '103.911583237057'}
# {'SEARCHVAL': 'KAKI BUKIT VILLE', 'BLK_NO': '508', 'ROAD_NAME': 'BEDOK NORTH AVENUE 3', 'BUILDING': 'KAKI BUKIT VILLE', 'ADDRESS': '508 BEDOK NORTH AVENUE 3 KAKI BUKIT VILLE SINGAPORE 460508', 'POSTAL': '460508', 'X': '39040.0247774674', 'Y': '35066.3497416321', 'LATITUDE': '1.33340012199511', 'LONGITUDE': '103.932519441614'}
# {'SEARCHVAL': 'BEDOK RESERVOIR GARDEN', 'BLK_NO': '720', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'BEDOK RESERVOIR GARDEN', 'ADDRESS': '720 BEDOK RESERVOIR ROAD BEDOK RESERVOIR GARDEN SINGAPORE 470720', 'POSTAL': '470720', 'X': '38190.1591502018', 'Y': '35350.7878217194', 'LATITUDE': '1.33597277354753', 'LONGITUDE': '103.924883020541'}
# {'SEARCHVAL': 'LONGVALE', 'BLK_NO': '765', 'ROAD_NAME': 'BEDOK RESERVOIR VIEW', 'BUILDING': 'LONGVALE', 'ADDRESS': '765 BEDOK RESERVOIR VIEW LONGVALE SINGAPORE 470765', 'POSTAL': '470765', 'X': '39426.2630763855', 'Y': '35349.5423547253', 'LATITUDE': '1.33596106828604', 'LONGITUDE': '103.935990113555'}
# {'SEARCHVAL': '10 CHAI CHEE ROAD SINGAPORE 467010', 'BLK_NO': '10', 'ROAD_NAME': 'CHAI CHEE ROAD', 'BUILDING': 'NIL', 'ADDRESS': '10 CHAI CHEE ROAD SINGAPORE 467010', 'POSTAL': '467010', 'X': '38181.3560703537', 'Y': '34389.1110518817', 'LATITUDE': '1.32727572366021', 'LONGITUDE': '103.924803599281'}
# {'SEARCHVAL': 'VISTA 8', 'BLK_NO': '185', 'ROAD_NAME': 'BEDOK NORTH ROAD', 'BUILDING': 'VISTA 8', 'ADDRESS': '185 BEDOK NORTH ROAD VISTA 8 SINGAPORE 460185', 'POSTAL': '460185', 'X': '39964.6664293949', 'Y': '34274.3538356517', 'LATITUDE': '1.32623725322603', 'LONGITUDE': '103.940827550178'}
# {'SEARCHVAL': '111 LENGKONG TIGA SINGAPORE 410111', 'BLK_NO': '111', 'ROAD_NAME': 'LENGKONG TIGA', 'BUILDING': 'NIL', 'ADDRESS': '111 LENGKONG TIGA SINGAPORE 410111', 'POSTAL': '410111', 'X': '36678.9711918877', 'Y': '34033.3459536117', 'LATITUDE': '1.32405877835385', 'LONGITUDE': '103.911303762731'}
# {'SEARCHVAL': 'LINEAR GREEN @ BEDOK', 'BLK_NO': '220B', 'ROAD_NAME': 'BEDOK CENTRAL', 'BUILDING': 'LINEAR GREEN @ BEDOK', 'ADDRESS': '220B BEDOK CENTRAL LINEAR GREEN @ BEDOK SINGAPORE 462220', 'POSTAL': '462220', 'X': '39243.5856246091', 'Y': '34190.2700730488', 'LATITUDE': '1.32547710525716', 'LONGITUDE': '103.934348226987'}
# {'SEARCHVAL': 'EUNOS RAINBOW', 'BLK_NO': '603', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS RAINBOW', 'ADDRESS': '603 BEDOK RESERVOIR ROAD EUNOS RAINBOW SINGAPORE 470603', 'POSTAL': '470603', 'X': '36808.0755534722', 'Y': '34690.5039246548', 'LATITUDE': '1.33000183975836', 'LONGITUDE': '103.912464022386'}
# {'SEARCHVAL': 'PING-AN GARDENS', 'BLK_NO': '21', 'ROAD_NAME': 'CHAI CHEE ROAD', 'BUILDING': 'PING-AN GARDENS', 'ADDRESS': '21 CHAI CHEE ROAD PING-AN GARDENS SINGAPORE 461021', 'POSTAL': '461021', 'X': '37916.6155465674', 'Y': '34223.5465430077', 'LATITUDE': '1.32577850604228', 'LONGITUDE': '103.922424710131'}
# {'SEARCHVAL': 'EUNOS DAMAI VILLE', 'BLK_NO': '672', 'ROAD_NAME': 'JALAN DAMAI', 'BUILDING': 'EUNOS DAMAI VILLE', 'ADDRESS': '672 JALAN DAMAI EUNOS DAMAI VILLE SINGAPORE 410672', 'POSTAL': '410672', 'X': '36395.5259924717', 'Y': '34920.1872827336', 'LATITUDE': '1.33207912967501', 'LONGITUDE': '103.908757101121'}
# {'SEARCHVAL': 'GARDEN HILL', 'BLK_NO': '415', 'ROAD_NAME': 'BEDOK NORTH AVENUE 2', 'BUILDING': 'GARDEN HILL', 'ADDRESS': '415 BEDOK NORTH AVENUE 2 GARDEN HILL SINGAPORE 460415', 'POSTAL': '460415', 'X': '38788.6559527237', 'Y': '34651.6693448462', 'LATITUDE': '1.32964999532963', 'LONGITUDE': '103.930260606366'}
# {'SEARCHVAL': 'LONGVALE', 'BLK_NO': '763', 'ROAD_NAME': 'BEDOK RESERVOIR VIEW', 'BUILDING': 'LONGVALE', 'ADDRESS': '763 BEDOK RESERVOIR VIEW LONGVALE SINGAPORE 470763', 'POSTAL': '470763', 'X': '39297.2214603322', 'Y': '35361.8137520235', 'LATITUDE': '1.33607209475067', 'LONGITUDE': '103.934830606324'}
# {'SEARCHVAL': 'PING-AN GARDENS', 'BLK_NO': '805', 'ROAD_NAME': 'CHAI CHEE ROAD', 'BUILDING': 'PING-AN GARDENS', 'ADDRESS': '805 CHAI CHEE ROAD PING-AN GARDENS SINGAPORE 460805', 'POSTAL': '460805', 'X': '37827.6623918153', 'Y': '34060.7264624853', 'LATITUDE': '1.32430604941035', 'LONGITUDE': '103.921625366639'}
# {'SEARCHVAL': 'RESERVOIR VIEW', 'BLK_NO': '723', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'RESERVOIR VIEW', 'ADDRESS': '723 BEDOK RESERVOIR ROAD RESERVOIR VIEW SINGAPORE 470723', 'POSTAL': '470723', 'X': '38643.9427854205', 'Y': '35459.3477893546', 'LATITUDE': '1.33695439373089', 'LONGITUDE': '103.928960561768'}
# {'SEARCHVAL': 'RESERVOIR VIEW', 'BLK_NO': '722', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'RESERVOIR VIEW', 'ADDRESS': '722 BEDOK RESERVOIR ROAD RESERVOIR VIEW SINGAPORE 470722', 'POSTAL': '470722', 'X': '38560.1667876756', 'Y': '35424.2479760572', 'LATITUDE': '1.33663699329345', 'LONGITUDE': '103.928207774481'}
# {'SEARCHVAL': 'LINEAR GREEN @ BEDOK', 'BLK_NO': '219C', 'ROAD_NAME': 'BEDOK CENTRAL', 'BUILDING': 'LINEAR GREEN @ BEDOK', 'ADDRESS': '219C BEDOK CENTRAL LINEAR GREEN @ BEDOK SINGAPORE 463219', 'POSTAL': '463219', 'X': '39151.3675835263', 'Y': '34121.5858433265', 'LATITUDE': '1.32485598421255', 'LONGITUDE': '103.933519574319'}
# {'SEARCHVAL': 'EUNOS TENAGA VILLE', 'BLK_NO': '640', 'ROAD_NAME': 'BEDOK RESERVOIR ROAD', 'BUILDING': 'EUNOS TENAGA VILLE', 'ADDRESS': '640 BEDOK RESERVOIR ROAD EUNOS TENAGA VILLE SINGAPORE 410640', 'POSTAL': '410640', 'X': '35972.1903446699', 'Y': '34922.6285166908', 'LATITUDE': '1.33210132151895', 'LONGITUDE': '103.904953194958'}
# {'SEARCHVAL': 'SIGLAP EAST', 'BLK_NO': '160', 'ROAD_NAME': 'BEDOK SOUTH AVENUE 3', 'BUILDING': 'SIGLAP EAST', 'ADDRESS': '160 BEDOK SOUTH AVENUE 3 SIGLAP EAST SINGAPORE 460160', 'POSTAL': '460160', 'X': '40451.6317049786', 'Y': '33502.8462673146', 'LATITUDE': '1.31925982986372', 'LONGITUDE': '103.945202877473'}
# {'SEARCHVAL': '94C BEDOK NORTH AVENUE 4 SINGAPORE 462094', 'BLK_NO': '94C', 'ROAD_NAME': 'BEDOK NORTH AVENUE 4', 'BUILDING': 'NIL', 'ADDRESS': '94C BEDOK NORTH AVENUE 4 SINGAPORE 462094', 'POSTAL': '462094', 'X': '40165.030826116', 'Y': '35090.0796895269', 'LATITUDE': '1.33361429610515', 'LONGITUDE': '103.942628254514'}
# {'SEARCHVAL': '22 SIN MING ROAD SINGAPORE 570022', 'BLK_NO': '22', 'ROAD_NAME': 'SIN MING ROAD', 'BUILDING': 'NIL', 'ADDRESS': '22 SIN MING ROAD SINGAPORE 570022', 'POSTAL': '570022', 'X': '28676.4225484971', 'Y': '37707.1341607384', 'LATITUDE': '1.3572844410824', 'LONGITUDE': '103.839396679952'}
# {'SEARCHVAL': 'SIN MING GARDEN', 'BLK_NO': '407', 'ROAD_NAME': 'SIN MING AVENUE', 'BUILDING': 'SIN MING GARDEN', 'ADDRESS': '407 SIN MING AVENUE SIN MING GARDEN SINGAPORE 570407', 'POSTAL': '570407', 'X': '28099.7196022905', 'Y': '38389.2439376432', 'LATITUDE': '1.36345320627772', 'LONGITUDE': '103.834214627275'}
# {'SEARCHVAL': 'BISHAN VIEW', 'BLK_NO': '105', 'ROAD_NAME': 'BISHAN STREET 12', 'BUILDING': 'BISHAN VIEW', 'ADDRESS': '105 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570105', 'POSTAL': '570105', 'X': '29563.2400869839', 'Y': '36447.7445298564', 'LATITUDE': '1.34589493632505', 'LONGITUDE': '103.847365252767'}
# {'SEARCHVAL': '167 BISHAN STREET 13 SINGAPORE 570167', 'BLK_NO': '167', 'ROAD_NAME': 'BISHAN STREET 13', 'BUILDING': 'NIL', 'ADDRESS': '167 BISHAN STREET 13 SINGAPORE 570167', 'POSTAL': '570167', 'X': '30456.9435917661', 'Y': '36680.8955394886', 'LATITUDE': '1.34800341123895', 'LONGITUDE': '103.855395747158'}
# {'SEARCHVAL': 'BISHAN VIEW', 'BLK_NO': '111', 'ROAD_NAME': 'BISHAN STREET 12', 'BUILDING': 'BISHAN VIEW', 'ADDRESS': '111 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570111', 'POSTAL': '570111', 'X': '29640.9649396911', 'Y': '36577.4040365312', 'LATITUDE': '1.34706752664279', 'LONGITUDE': '103.848063665404'}
# {'SEARCHVAL': '181 BISHAN STREET 13 SINGAPORE 570181', 'BLK_NO': '181', 'ROAD_NAME': 'BISHAN STREET 13', 'BUILDING': 'NIL', 'ADDRESS': '181 BISHAN STREET 13 SINGAPORE 570181', 'POSTAL': '570181', 'X': '30176.801779557', 'Y': '36806.3608419262', 'LATITUDE': '1.34913809640172', 'LONGITUDE': '103.852878507674'}
# {'SEARCHVAL': '166 BISHAN STREET 13 SINGAPORE 570166', 'BLK_NO': '166', 'ROAD_NAME': 'BISHAN STREET 13', 'BUILDING': 'NIL', 'ADDRESS': '166 BISHAN STREET 13 SINGAPORE 570166', 'POSTAL': '570166', 'X': '30438.0271915905', 'Y': '36775.9941543154', 'LATITUDE': '1.34886345078255', 'LONGITUDE': '103.855225779214'}
# {'SEARCHVAL': 'BISHAN VIEW', 'BLK_NO': '109', 'ROAD_NAME': 'BISHAN STREET 12', 'BUILDING': 'BISHAN VIEW', 'ADDRESS': '109 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570109', 'POSTAL': '570109', 'X': '29632.7857435234', 'Y': '36542.3594017662', 'LATITUDE': '1.34675059587742', 'LONGITUDE': '103.847990168368'}
# {'SEARCHVAL': 'BISHAN VIEW', 'BLK_NO': '115', 'ROAD_NAME': 'BISHAN STREET 12', 'BUILDING': 'BISHAN VIEW', 'ADDRESS': '115 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570115', 'POSTAL': '570115', 'X': '29717.3597566588', 'Y': '36671.4885225613', 'LATITUDE': '1.34791838898824', 'LONGITUDE': '103.84875012549'}
# {'SEARCHVAL': '260 BISHAN STREET 22 SINGAPORE 570260', 'BLK_NO': '260', 'ROAD_NAME': 'BISHAN STREET 22', 'BUILDING': 'NIL', 'ADDRESS': '260 BISHAN STREET 22 SINGAPORE 570260', 'POSTAL': '570260', 'X': '28987.0008462882', 'Y': '37964.70017354', 'LATITUDE': '1.35961376765045', 'LONGITUDE': '103.842187438495'}
# {'SEARCHVAL': 'NATURA LOFT', 'BLK_NO': '275A', 'ROAD_NAME': 'BISHAN STREET 24', 'BUILDING': 'NATURA LOFT', 'ADDRESS': '275A BISHAN STREET 24 NATURA LOFT SINGAPORE 571275', 'POSTAL': '571275', 'X': '29135.2732560653', 'Y': '37646.4244853444', 'LATITUDE': '1.35673539047075', 'LONGITUDE': '103.843519752733'}
# {'SEARCHVAL': '214 BISHAN STREET 23 SINGAPORE 570214', 'BLK_NO': '214', 'ROAD_NAME': 'BISHAN STREET 23', 'BUILDING': 'NIL', 'ADDRESS': '214 BISHAN STREET 23 SINGAPORE 570214', 'POSTAL': '570214', 'X': '29667.6393873096', 'Y': '37732.2893674504', 'LATITUDE': '1.35751189682984', 'LONGITUDE': '103.848303415822'}
# {'SEARCHVAL': '182 BISHAN STREET 13 SINGAPORE 570182', 'BLK_NO': '182', 'ROAD_NAME': 'BISHAN STREET 13', 'BUILDING': 'NIL', 'ADDRESS': '182 BISHAN STREET 13 SINGAPORE 570182', 'POSTAL': '570182', 'X': '30195.7973910468', 'Y': '36924.4249564502', 'LATITUDE': '1.35020582481902', 'LONGITUDE': '103.853049203745'}
# {'SEARCHVAL': 'SIN MING COURT', 'BLK_NO': '448', 'ROAD_NAME': 'BRIGHT HILL DRIVE', 'BUILDING': 'SIN MING COURT', 'ADDRESS': '448 BRIGHT HILL DRIVE SIN MING COURT SINGAPORE 570448', 'POSTAL': '570448', 'X': '27789.9989478178', 'Y': '37831.1684534419', 'LATITUDE': '1.35840616993705', 'LONGITUDE': '103.831431580561'}
# {'SEARCHVAL': 'SIN MING GARDEN', 'BLK_NO': '402', 'ROAD_NAME': 'SIN MING AVENUE', 'BUILDING': 'SIN MING GARDEN', 'ADDRESS': '402 SIN MING AVENUE SIN MING GARDEN SINGAPORE 570402', 'POSTAL': '570402', 'X': '27937.7132462421', 'Y': '38313.5731005799', 'LATITUDE': '1.36276886630643', 'LONGITUDE': '103.832758890176'}
# {'SEARCHVAL': '128 BISHAN STREET 12 SINGAPORE 570128', 'BLK_NO': '128', 'ROAD_NAME': 'BISHAN STREET 12', 'BUILDING': 'NIL', 'ADDRESS': '128 BISHAN STREET 12 SINGAPORE 570128', 'POSTAL': '570128', 'X': '29908.4102710392', 'Y': '36469.1301013399', 'LATITUDE': '1.34608831988483', 'LONGITUDE': '103.850466820468'}
# {'SEARCHVAL': 'SHUNFU GARDENS', 'BLK_NO': '303', 'ROAD_NAME': 'SHUNFU ROAD', 'BUILDING': 'SHUNFU GARDENS', 'ADDRESS': '303 SHUNFU ROAD SHUNFU GARDENS SINGAPORE 570303', 'POSTAL': '570303', 'X': '28574.0194216967', 'Y': '36876.1622023936', 'LATITUDE': '1.34976942860988', 'LONGITUDE': '103.83847650474'}
# {'SEARCHVAL': '231 BISHAN STREET 23 SINGAPORE 570231', 'BLK_NO': '231', 'ROAD_NAME': 'BISHAN STREET 23', 'BUILDING': 'NIL', 'ADDRESS': '231 BISHAN STREET 23 SINGAPORE 570231', 'POSTAL': '570231', 'X': '29394.1230551284', 'Y': '37707.8874400482', 'LATITUDE': '1.35729122854977', 'LONGITUDE': '103.845845690555'}
# {'SEARCHVAL': '134 BISHAN STREET 12 SINGAPORE 570134', 'BLK_NO': '134', 'ROAD_NAME': 'BISHAN STREET 12', 'BUILDING': 'NIL', 'ADDRESS': '134 BISHAN STREET 12 SINGAPORE 570134', 'POSTAL': '570134', 'X': '30087.9181806324', 'Y': '36394.2421154063', 'LATITUDE': '1.34541104764477', 'LONGITUDE': '103.852079804354'}
# {'SEARCHVAL': '342 BUKIT BATOK STREET 34 SINGAPORE 650342', 'BLK_NO': '342', 'ROAD_NAME': 'BUKIT BATOK STREET 34', 'BUILDING': 'NIL', 'ADDRESS': '342 BUKIT BATOK STREET 34 SINGAPORE 650342', 'POSTAL': '650342', 'X': '18569.0280565582', 'Y': '38293.2123727556', 'LATITUDE': '1.36258323081948', 'LONGITUDE': '103.748574945077'}
# {'SEARCHVAL': '530 BUKIT BATOK STREET 51 SINGAPORE 650530', 'BLK_NO': '530', 'ROAD_NAME': 'BUKIT BATOK STREET 51', 'BUILDING': 'NIL', 'ADDRESS': '530 BUKIT BATOK STREET 51 SINGAPORE 650530', 'POSTAL': '650530', 'X': '18849.2776227901', 'Y': '37585.3856153619', 'LATITUDE': '1.35618199232172', 'LONGITUDE': '103.751093390961'}
# {'SEARCHVAL': '145 BUKIT BATOK STREET 11 SINGAPORE 650145', 'BLK_NO': '145', 'ROAD_NAME': 'BUKIT BATOK STREET 11', 'BUILDING': 'NIL', 'ADDRESS': '145 BUKIT BATOK STREET 11 SINGAPORE 650145', 'POSTAL': '650145', 'X': '18029.2176357908', 'Y': '36898.8612832986', 'LATITUDE': '1.34997305498668', 'LONGITUDE': '103.743724852615'}
# {'SEARCHVAL': '528 BUKIT BATOK STREET 51 SINGAPORE 650528', 'BLK_NO': '528', 'ROAD_NAME': 'BUKIT BATOK STREET 51', 'BUILDING': 'NIL', 'ADDRESS': '528 BUKIT BATOK STREET 51 SINGAPORE 650528', 'POSTAL': '650528', 'X': '18849.1051860871', 'Y': '37637.2979315538', 'LATITUDE': '1.35665146828264', 'LONGITUDE': '103.751091825657'}
# {'SEARCHVAL': 'GUILIN BREEZE', 'BLK_NO': '537', 'ROAD_NAME': 'BUKIT BATOK STREET 52', 'BUILDING': 'GUILIN BREEZE', 'ADDRESS': '537 BUKIT BATOK STREET 52 GUILIN BREEZE SINGAPORE 650537', 'POSTAL': '650537', 'X': '18825.2906089099', 'Y': '37467.4219300076', 'LATITUDE': '1.35511516448647', 'LONGITUDE': '103.750877888291'}
# {'SEARCHVAL': '213 BUKIT BATOK STREET 21 SINGAPORE 650213', 'BLK_NO': '213', 'ROAD_NAME': 'BUKIT BATOK STREET 21', 'BUILDING': 'NIL', 'ADDRESS': '213 BUKIT BATOK STREET 21 SINGAPORE 650213', 'POSTAL': '650213', 'X': '19005.4350239327', 'Y': '36550.0071224086', 'LATITUDE': '1.34681845451426', 'LONGITUDE': '103.752496875347'}
# {'SEARCHVAL': '219 BUKIT BATOK STREET 21 SINGAPORE 650219', 'BLK_NO': '219', 'ROAD_NAME': 'BUKIT BATOK STREET 21', 'BUILDING': 'NIL', 'ADDRESS': '219 BUKIT BATOK STREET 21 SINGAPORE 650219', 'POSTAL': '650219', 'X': '19283.9763559671', 'Y': '36592.9944090471', 'LATITUDE': '1.34720729813155', 'LONGITUDE': '103.754999726682'}
# {'SEARCHVAL': 'GOMBAK GARDENS', 'BLK_NO': '235', 'ROAD_NAME': 'BUKIT BATOK EAST AVENUE 5', 'BUILDING': 'GOMBAK GARDENS', 'ADDRESS': '235 BUKIT BATOK EAST AVENUE 5 GOMBAK GARDENS SINGAPORE 650235', 'POSTAL': '650235', 'X': '19428.7369532008', 'Y': '36734.108137995', 'LATITUDE': '1.34848352110457', 'LONGITUDE': '103.756300449103'}
# {'SEARCHVAL': '130 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650130', 'BLK_NO': '130', 'ROAD_NAME': 'BUKIT BATOK WEST AVENUE 6', 'BUILDING': 'NIL', 'ADDRESS': '130 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650130', 'POSTAL': '650130', 'X': '18266.5455061039', 'Y': '37019.1809377', 'LATITUDE': '1.35106126001126', 'LONGITUDE': '103.745857351625'}
# {'SEARCHVAL': '212 BUKIT BATOK STREET 21 SINGAPORE 650212', 'BLK_NO': '212', 'ROAD_NAME': 'BUKIT BATOK STREET 21', 'BUILDING': 'NIL', 'ADDRESS': '212 BUKIT BATOK STREET 21 SINGAPORE 650212', 'POSTAL': '650212', 'X': '18974.3265588433', 'Y': '36591.4026460517', 'LATITUDE': '1.34719281119437', 'LONGITUDE': '103.752217334445'}
# {'SEARCHVAL': '346 BUKIT BATOK STREET 34 SINGAPORE 650346', 'BLK_NO': '346', 'ROAD_NAME': 'BUKIT BATOK STREET 34', 'BUILDING': 'NIL', 'ADDRESS': '346 BUKIT BATOK STREET 34 SINGAPORE 650346', 'POSTAL': '650346', 'X': '18790.0613697134', 'Y': '38280.8394263722', 'LATITUDE': '1.362471403915', 'LONGITUDE': '103.750561080651'}
# {'SEARCHVAL': '226 BUKIT BATOK CENTRAL SINGAPORE 650226', 'BLK_NO': '226', 'ROAD_NAME': 'BUKIT BATOK CENTRAL', 'BUILDING': 'NIL', 'ADDRESS': '226 BUKIT BATOK CENTRAL SINGAPORE 650226', 'POSTAL': '650226', 'X': '19080.829544574', 'Y': '36761.747317059', 'LATITUDE': '1.34873337819665', 'LONGITUDE': '103.753174278473'}
# {'SEARCHVAL': 'GOMBAK VIEW', 'BLK_NO': '247', 'ROAD_NAME': 'BUKIT BATOK EAST AVENUE 5', 'BUILDING': 'GOMBAK VIEW', 'ADDRESS': '247 BUKIT BATOK EAST AVENUE 5 GOMBAK VIEW SINGAPORE 650247', 'POSTAL': '650247', 'X': '19504.4003443411', 'Y': '36893.7419078723', 'LATITUDE': '1.34992721242157', 'LONGITUDE': '103.75698028632'}
# {'SEARCHVAL': '169 BUKIT BATOK WEST AVENUE 8 SINGAPORE 650169', 'BLK_NO': '169', 'ROAD_NAME': 'BUKIT BATOK WEST AVENUE 8', 'BUILDING': 'NIL', 'ADDRESS': '169 BUKIT BATOK WEST AVENUE 8 SINGAPORE 650169', 'POSTAL': '650169', 'X': '17715.8621899569', 'Y': '36526.708463015', 'LATITUDE': '1.34660733553492', 'LONGITUDE': '103.740909286964'}
# {'SEARCHVAL': '154 BUKIT BATOK STREET 11 SINGAPORE 650154', 'BLK_NO': '154', 'ROAD_NAME': 'BUKIT BATOK STREET 11', 'BUILDING': 'NIL', 'ADDRESS': '154 BUKIT BATOK STREET 11 SINGAPORE 650154', 'POSTAL': '650154', 'X': '18058.0542162899', 'Y': '36651.4517529681', 'LATITUDE': '1.34773558349504', 'LONGITUDE': '103.743984048754'}
# {'SEARCHVAL': '260 BUKIT BATOK EAST AVENUE 4 SINGAPORE 650260', 'BLK_NO': '260', 'ROAD_NAME': 'BUKIT BATOK EAST AVENUE 4', 'BUILDING': 'NIL', 'ADDRESS': '260 BUKIT BATOK EAST AVENUE 4 SINGAPORE 650260', 'POSTAL': '650260', 'X': '19731.5192777663', 'Y': '37002.6932405382', 'LATITUDE': '1.35091259231107', 'LONGITUDE': '103.759021061327'}
# ...
# {'SEARCHVAL': 'EASTLINK I @ CANBERRA', 'BLK_NO': '131B', 'ROAD_NAME': 'CANBERRA CRESCENT', 'BUILDING': 'EASTLINK I @ CANBERRA', 'ADDRESS': '131B CANBERRA CRESCENT EASTLINK I @ CANBERRA SINGAPORE 752131', 'POSTAL': '752131', 'X': '27726.1310504675', 'Y': '47311.9097142201', 'LATITUDE': '1.4441465844546', 'LONGITUDE': '103.830857595253'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '455B', 'ROAD_NAME': 'SENGKANG WEST AVENUE', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '455B SENGKANG WEST AVENUE FERNVALE WOODS SINGAPORE 792455', 'POSTAL': '792455', 'X': '32109.729354891', 'Y': '41547.6258912347', 'LATITUDE': '1.39201619223955', 'LONGITUDE': '103.870247728472'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '458B', 'ROAD_NAME': 'SENGKANG WEST ROAD', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '458B SENGKANG WEST ROAD FERNVALE WOODS SINGAPORE 792458', 'POSTAL': '792458', 'X': '32104.0491439952', 'Y': '41649.5559899863', 'LATITUDE': '1.39293801208567', 'LONGITUDE': '103.870196701638'}
# {'SEARCHVAL': 'ALKAFF VISTA', 'BLK_NO': '105A', 'ROAD_NAME': 'BIDADARI PARK DRIVE', 'BUILDING': 'ALKAFF VISTA', 'ADDRESS': '105A BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 341105', 'POSTAL': '341105', 'X': '32130.1762556639', 'Y': '35133.2631429676', 'LATITUDE': '1.33400699237548', 'LONGITUDE': '103.870430572231'}
# {'SEARCHVAL': 'ALKAFF VISTA', 'BLK_NO': '106A', 'ROAD_NAME': 'BIDADARI PARK DRIVE', 'BUILDING': 'ALKAFF VISTA', 'ADDRESS': '106A BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 341106', 'POSTAL': '341106', 'X': '32222.4509584131', 'Y': '35147.8612704426', 'LATITUDE': '1.33413899991746', 'LONGITUDE': '103.871259715052'}
# {'SEARCHVAL': 'EASTLINK I @ CANBERRA', 'BLK_NO': '131A', 'ROAD_NAME': 'CANBERRA CRESCENT', 'BUILDING': 'EASTLINK I @ CANBERRA', 'ADDRESS': '131A CANBERRA CRESCENT EASTLINK I @ CANBERRA SINGAPORE 751131', 'POSTAL': '751131', 'X': '27745.2948914105', 'Y': '47265.4007779453', 'LATITUDE': '1.44372597469524', 'LONGITUDE': '103.831029801721'}
# {'SEARCHVAL': 'EASTLINK I @ CANBERRA', 'BLK_NO': '132A', 'ROAD_NAME': 'CANBERRA CRESCENT', 'BUILDING': 'EASTLINK I @ CANBERRA', 'ADDRESS': '132A CANBERRA CRESCENT EASTLINK I @ CANBERRA SINGAPORE 751132', 'POSTAL': '751132', 'X': '27774.7603498073', 'Y': '47235.3685212843', 'LATITUDE': '1.44345437411826', 'LONGITUDE': '103.831294578169'}
# {'SEARCHVAL': 'EASTCREEK @ CANBERRA', 'BLK_NO': '101A', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTCREEK @ CANBERRA', 'ADDRESS': '101A CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 751101', 'POSTAL': '751101', 'X': '27681.2301008264', 'Y': '48151.4330438618', 'LATITUDE': '1.45173892803325', 'LONGITUDE': '103.83045410628'}
# {'SEARCHVAL': 'ANCHORVALE PLAINS', 'BLK_NO': '353A', 'ROAD_NAME': 'ANCHORVALE LANE', 'BUILDING': 'ANCHORVALE PLAINS', 'ADDRESS': '353A ANCHORVALE LANE ANCHORVALE PLAINS SINGAPORE 541353', 'POSTAL': '541353', 'X': '33820.002827079', 'Y': '41745.6216366235', 'LATITUDE': '1.39380650147896', 'LONGITUDE': '103.885615916234'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '458A', 'ROAD_NAME': 'SENGKANG WEST ROAD', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '458A SENGKANG WEST ROAD FERNVALE WOODS SINGAPORE 791458', 'POSTAL': '791458', 'X': '32034.5499790786', 'Y': '41652.915675642', 'LATITUDE': '1.39296840561775', 'LONGITUDE': '103.869572197299'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '458C', 'ROAD_NAME': 'SENGKANG WEST ROAD', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '458C SENGKANG WEST ROAD FERNVALE WOODS SINGAPORE 793458', 'POSTAL': '793458', 'X': '32179.552054286', 'Y': '41640.6374075115', 'LATITUDE': '1.39285734486634', 'LONGITUDE': '103.870875153546'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '610C', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '610C TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 523610', 'POSTAL': '523610', 'X': '39378.0788980145', 'Y': '38496.1410125233', 'LATITUDE': '1.36441776002022', 'LONGITUDE': '103.935558340158'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '610A', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '610A TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 521610', 'POSTAL': '521610', 'X': '39529.1191938305', 'Y': '38505.0529965758', 'LATITUDE': '1.36449829827687', 'LONGITUDE': '103.936915541696'}
# {'SEARCHVAL': 'TAMPINES GREENVIEW', 'BLK_NO': '612B', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENVIEW', 'ADDRESS': '612B TAMPINES NORTH DRIVE 1 TAMPINES GREENVIEW SINGAPORE 522612', 'POSTAL': '522612', 'X': '39403.8349242033', 'Y': '38600.3785002083', 'LATITUDE': '1.36536043524759', 'LONGITUDE': '103.935789815182'}
# {'SEARCHVAL': 'ALKAFF VISTA', 'BLK_NO': '105B', 'ROAD_NAME': 'BIDADARI PARK DRIVE', 'BUILDING': 'ALKAFF VISTA', 'ADDRESS': '105B BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 342105', 'POSTAL': '342105', 'X': '32136.8359385133', 'Y': '35074.3319537621', 'LATITUDE': '1.33347403879152', 'LONGITUDE': '103.870490405284'}
# {'SEARCHVAL': 'EASTLINK I @ CANBERRA', 'BLK_NO': '132C', 'ROAD_NAME': 'CANBERRA VIEW', 'BUILDING': 'EASTLINK I @ CANBERRA', 'ADDRESS': '132C CANBERRA VIEW EASTLINK I @ CANBERRA SINGAPORE 753132', 'POSTAL': '753132', 'X': '27737.2713634828', 'Y': '47149.0523738097', 'LATITUDE': '1.44267376186975', 'LONGITUDE': '103.8309577035'}
# {'SEARCHVAL': 'EASTCREEK @ CANBERRA', 'BLK_NO': '101B', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTCREEK @ CANBERRA', 'ADDRESS': '101B CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 752101', 'POSTAL': '752101', 'X': '27761.4439201029', 'Y': '48143.0486610327', 'LATITUDE': '1.45166310353079', 'LONGITUDE': '103.831174909166'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '456A', 'ROAD_NAME': 'SENGKANG WEST ROAD', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '456A SENGKANG WEST ROAD FERNVALE WOODS SINGAPORE 791456', 'POSTAL': '791456', 'X': '32069.0849918006', 'Y': '41508.2017213721', 'LATITUDE': '1.39165965999065', 'LONGITUDE': '103.869882501471'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '609D', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '609D TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 524609', 'POSTAL': '524609', 'X': '39581.7351498418', 'Y': '38435.5866724215', 'LATITUDE': '1.36387005013131', 'LONGITUDE': '103.93738830427'}
# {'SEARCHVAL': 'TAMPINES GREENVIEW', 'BLK_NO': '612A', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENVIEW', 'ADDRESS': '612A TAMPINES NORTH DRIVE 1 TAMPINES GREENVIEW SINGAPORE 521612', 'POSTAL': '521612', 'X': '39337.7543464396', 'Y': '38592.1828987934', 'LATITUDE': '1.36528634266006', 'LONGITUDE': '103.935196033623'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '609C', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '609C TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 523609', 'POSTAL': '523609', 'X': '39484.5455016289', 'Y': '38415.6491818149', 'LATITUDE': '1.3636897807061', 'LONGITUDE': '103.936514982808'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '610B', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '610B TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 522610', 'POSTAL': '522610', 'X': '39427.9782722192', 'Y': '38496.1493664868', 'LATITUDE': '1.3644178163568', 'LONGITUDE': '103.936006719423'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '608C', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '608C TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 523608', 'POSTAL': '523608', 'X': '39472.0464890925', 'Y': '38352.1111752205', 'LATITUDE': '1.36311517141264', 'LONGITUDE': '103.936402646417'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '608A', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '608A TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 521608', 'POSTAL': '521608', 'X': '39329.1257312493', 'Y': '38355.7257778347', 'LATITUDE': '1.36314791550448', 'LONGITUDE': '103.93511840985'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '609A', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '609A TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 521609', 'POSTAL': '521609', 'X': '39355.7604067372', 'Y': '38407.2780563626', 'LATITUDE': '1.36361412499017', 'LONGITUDE': '103.935357759734'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '609B', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '609B TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 522609', 'POSTAL': '522609', 'X': '39391.6126518417', 'Y': '38407.2846850511', 'LATITUDE': '1.36361417117643', 'LONGITUDE': '103.935679916041'}
# {'SEARCHVAL': 'DAWSON VISTA', 'BLK_NO': '79', 'ROAD_NAME': 'DAWSON ROAD', 'BUILDING': 'DAWSON VISTA', 'ADDRESS': '79 DAWSON ROAD DAWSON VISTA SINGAPORE 141079', 'POSTAL': '141079', 'X': '25441.1974788317', 'Y': '30774.8071813639', 'LATITUDE': '1.29459083160081', 'LONGITUDE': '103.810326636243'}
# {'SEARCHVAL': 'EASTDELTA @ CANBERRA', 'BLK_NO': '126C', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTDELTA @ CANBERRA', 'ADDRESS': '126C CANBERRA STREET EASTDELTA @ CANBERRA SINGAPORE 753126', 'POSTAL': '753126', 'X': '28183.1818723846', 'Y': '47532.3992327806', 'LATITUDE': '1.44614061239177', 'LONGITUDE': '103.834964649867'}
# {'SEARCHVAL': 'EASTCREEK @ CANBERRA', 'BLK_NO': '102A', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTCREEK @ CANBERRA', 'ADDRESS': '102A CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 751102', 'POSTAL': '751102', 'X': '27878.5864955941', 'Y': '48091.1669760384', 'LATITUDE': '1.45119390519494', 'LONGITUDE': '103.832227554636'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '456B', 'ROAD_NAME': 'SENGKANG WEST ROAD', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '456B SENGKANG WEST ROAD FERNVALE WOODS SINGAPORE 792456', 'POSTAL': '792456', 'X': '32072.0051863333', 'Y': '41558.6311787739', 'LATITUDE': '1.39211572540583', 'LONGITUDE': '103.869908748735'}
# {'SEARCHVAL': 'ANCHORVALE PLAINS', 'BLK_NO': '353B', 'ROAD_NAME': 'ANCHORVALE LANE', 'BUILDING': 'ANCHORVALE PLAINS', 'ADDRESS': '353B ANCHORVALE LANE ANCHORVALE PLAINS SINGAPORE 542353', 'POSTAL': '542353', 'X': '33846.8139346438', 'Y': '41805.4785418436', 'LATITUDE': '1.39434782021906', 'LONGITUDE': '103.88585684721'}
# {'SEARCHVAL': 'TAMPINES GREENWEAVE', 'BLK_NO': '608B', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENWEAVE', 'ADDRESS': '608B TAMPINES NORTH DRIVE 1 TAMPINES GREENWEAVE SINGAPORE 522608', 'POSTAL': '522608', 'X': '39422.3514540456', 'Y': '38353.276432056', 'LATITUDE': '1.36312572875358', 'LONGITUDE': '103.935956103971'}
# {'SEARCHVAL': 'TAMPINES GREENVIEW', 'BLK_NO': '613B', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENVIEW', 'ADDRESS': '613B TAMPINES NORTH DRIVE 1 TAMPINES GREENVIEW SINGAPORE 522613', 'POSTAL': '522613', 'X': '39428.1491047191', 'Y': '38680.0813656524', 'LATITUDE': '1.366081228979', 'LONGITUDE': '103.936008325034'}
# {'SEARCHVAL': 'ALKAFF LAKEVIEW', 'BLK_NO': '115C', 'ROAD_NAME': 'ALKAFF CRESCENT', 'BUILDING': 'ALKAFF LAKEVIEW', 'ADDRESS': '115C ALKAFF CRESCENT ALKAFF LAKEVIEW SINGAPORE 343115', 'POSTAL': '343115', 'X': '32403.5045328625', 'Y': '35489.4825334083', 'LATITUDE': '1.33722847497236', 'LONGITUDE': '103.872886634076'}
# {'SEARCHVAL': 'DAWSON VISTA', 'BLK_NO': '78', 'ROAD_NAME': 'DAWSON ROAD', 'BUILDING': 'DAWSON VISTA', 'ADDRESS': '78 DAWSON ROAD DAWSON VISTA SINGAPORE 141078', 'POSTAL': '141078', 'X': '25415.1916509736', 'Y': '30694.5215664282', 'LATITUDE': '1.29386475464004', 'LONGITUDE': '103.810092969298'}
# {'SEARCHVAL': 'EASTCREEK @ CANBERRA', 'BLK_NO': '102B', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTCREEK @ CANBERRA', 'ADDRESS': '102B CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 752102', 'POSTAL': '752102', 'X': '27790.5397458831', 'Y': '48096.2312637344', 'LATITUDE': '1.45123970424367', 'LONGITUDE': '103.83143636512'}
# {'SEARCHVAL': 'EASTCREEK @ CANBERRA', 'BLK_NO': '103A', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTCREEK @ CANBERRA', 'ADDRESS': '103A CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 751103', 'POSTAL': '751103', 'X': '27690.1218658667', 'Y': '48073.0501046516', 'LATITUDE': '1.45103006132424', 'LONGITUDE': '103.830534008712'}
# {'SEARCHVAL': 'EASTCREEK @ CANBERRA', 'BLK_NO': '103B', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTCREEK @ CANBERRA', 'ADDRESS': '103B CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 752103', 'POSTAL': '752103', 'X': '27768.5473315939', 'Y': '48021.7358535491', 'LATITUDE': '1.45056599465441', 'LONGITUDE': '103.831238741555'}
# {'SEARCHVAL': 'EASTDELTA @ CANBERRA', 'BLK_NO': '126D', 'ROAD_NAME': 'CANBERRA STREET', 'BUILDING': 'EASTDELTA @ CANBERRA', 'ADDRESS': '126D CANBERRA STREET EASTDELTA @ CANBERRA SINGAPORE 754126', 'POSTAL': '754126', 'X': '28164.0242061103', 'Y': '47580.4346440118', 'LATITUDE': '1.4465750273277', 'LONGITUDE': '103.834792499436'}
# {'SEARCHVAL': 'ANCHORVALE PLAINS', 'BLK_NO': '355A', 'ROAD_NAME': 'ANCHORVALE LANE', 'BUILDING': 'ANCHORVALE PLAINS', 'ADDRESS': '355A ANCHORVALE LANE ANCHORVALE PLAINS SINGAPORE 541355', 'POSTAL': '541355', 'X': '33763.3906799816', 'Y': '41652.9829311017', 'LATITUDE': '1.39296872192969', 'LONGITUDE': '103.885107193078'}
# {'SEARCHVAL': 'FERNVALE WOODS', 'BLK_NO': '457A', 'ROAD_NAME': 'SENGKANG WEST ROAD', 'BUILDING': 'FERNVALE WOODS', 'ADDRESS': '457A SENGKANG WEST ROAD FERNVALE WOODS SINGAPORE 791457', 'POSTAL': '791457', 'X': '32103.1452814657', 'Y': '41600.9418549053', 'LATITUDE': '1.39249836351383', 'LONGITUDE': '103.870188572891'}
# {'SEARCHVAL': 'TAMPINES GREENVIEW', 'BLK_NO': '613A', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENVIEW', 'ADDRESS': '613A TAMPINES NORTH DRIVE 1 TAMPINES GREENVIEW SINGAPORE 521613', 'POSTAL': '521613', 'X': '39351.869820646', 'Y': '38648.2615424097', 'LATITUDE': '1.3657934916842', 'LONGITUDE': '103.935322892026'}
# {'SEARCHVAL': 'ALKAFF LAKEVIEW', 'BLK_NO': '115A', 'ROAD_NAME': 'ALKAFF CRESCENT', 'BUILDING': 'ALKAFF LAKEVIEW', 'ADDRESS': '115A ALKAFF CRESCENT ALKAFF LAKEVIEW SINGAPORE 341115', 'POSTAL': '341115', 'X': '32389.5174554428', 'Y': '35403.7161130533', 'LATITUDE': '1.33645283610396', 'LONGITUDE': '103.87276093968'}
# {'SEARCHVAL': 'BUANGKOK WOODS', 'BLK_NO': '994B', 'ROAD_NAME': 'BUANGKOK LINK', 'BUILDING': 'BUANGKOK WOODS', 'ADDRESS': '994B BUANGKOK LINK BUANGKOK WOODS SINGAPORE 532994', 'POSTAL': '532994', 'X': '33582.8586531589', 'Y': '40857.1608492993', 'LATITUDE': '1.38577163049659', 'LONGITUDE': '103.883484818974'}
# {'SEARCHVAL': 'BUANGKOK WOODS', 'BLK_NO': '993A', 'ROAD_NAME': 'BUANGKOK LINK', 'BUILDING': 'BUANGKOK WOODS', 'ADDRESS': '993A BUANGKOK LINK BUANGKOK WOODS SINGAPORE 531993', 'POSTAL': '531993', 'X': '33543.2750012893', 'Y': '40754.0170044024', 'LATITUDE': '1.38483884242613', 'LONGITUDE': '103.883129110308'}
# {'SEARCHVAL': 'ANCHORVALE PLAINS', 'BLK_NO': '356A', 'ROAD_NAME': 'ANCHORVALE LANE', 'BUILDING': 'ANCHORVALE PLAINS', 'ADDRESS': '356A ANCHORVALE LANE ANCHORVALE PLAINS SINGAPORE 541356', 'POSTAL': '541356', 'X': '33730.5348744607', 'Y': '41704.6266189404', 'LATITUDE': '1.39343577522561', 'LONGITUDE': '103.884811967949'}
# {'SEARCHVAL': 'ANCHORVALE PLAINS', 'BLK_NO': '356B', 'ROAD_NAME': 'ANCHORVALE LANE', 'BUILDING': 'ANCHORVALE PLAINS', 'ADDRESS': '356B ANCHORVALE LANE ANCHORVALE PLAINS SINGAPORE 542356', 'POSTAL': '542356', 'X': '33696.5745599456', 'Y': '41756.6910014842', 'LATITUDE': '1.39390663331416', 'LONGITUDE': '103.884506817902'}
# {'SEARCHVAL': 'TAMPINES GREENVIEW', 'BLK_NO': '614A', 'ROAD_NAME': 'TAMPINES NORTH DRIVE 1', 'BUILDING': 'TAMPINES GREENVIEW', 'ADDRESS': '614A TAMPINES NORTH DRIVE 1 TAMPINES GREENVIEW SINGAPORE 521614', 'POSTAL': '521614', 'X': '39504.2864016807', 'Y': '38548.8937798198', 'LATITUDE': '1.36489478768898', 'LONGITUDE': '103.936692419369'}

# %% [markdown]
# ### Generate distance to MRT station
# Using haversin formula

# %%
import numpy as np
from math import radians, cos, sin, sqrt, atan2

bus_stops = gpd.read_file("../../data/raw/BusStopLocation_Nov2024/BusStop.shp")
MRT_stops = pd.read_csv("../../data/raw/MRT Stations.csv")

def haversine(lat1, lon1, lat2, lon2):
    R = 6371000  # radius of Earth in meters
    phi1, phi2 = radians(lat1), radians(lat2)
    dphi = radians(lat2 - lat1)
    dlambda = radians(lon2 - lon1)
    a = sin(dphi/2)**2 + cos(phi1)*cos(phi2)*sin(dlambda/2)**2
    return 2*R*atan2(sqrt(a), sqrt(1 - a))

from pyproj import Transformer

transformer = Transformer.from_crs("EPSG:3414", "EPSG:4326", always_xy=True)

def svy21_to_wgs84(easting, northing):
    lon, lat = transformer.transform(easting, northing)
    return lat, lon


bus_stops['x_coord'] = bus_stops.geometry.apply(lambda geom: geom.x)
bus_stops['y_coord'] = bus_stops.geometry.apply(lambda geom: geom.y)
bus_stops['Latitude'], bus_stops['Longitude'] = zip(*bus_stops.apply(lambda row: svy21_to_wgs84(row['x_coord'], row['y_coord']), axis=1))

def calculate_nearest_stops(row, mrt_stops, bus_stops):
    hdb_lat, hdb_lon = row['latitude'], row['longitude']
    if pd.isnull(hdb_lat) or pd.isnull(hdb_lon):
        return pd.Series([None, None])

    mrt_distances = mrt_stops.apply(lambda x: haversine(hdb_lat, hdb_lon, x['Latitude'], x['Longitude']), axis=1)
    nearest_mrt_distance = mrt_distances.min()

    bus_distances = bus_stops.apply(lambda x: haversine(hdb_lat, hdb_lon, x['Latitude'], x['Longitude']), axis=1)
    nearest_bus_distance = bus_distances.min()

    return pd.Series([nearest_mrt_distance, nearest_bus_distance])


unique_addresses = df_resale[['latitude', 'longitude']].drop_duplicates().reset_index(drop=True)
unique_addresses[['nearest_mrt_distance', 'nearest_bus_distance']] = unique_addresses.apply(calculate_nearest_stops, axis=1, mrt_stops=MRT_stops, bus_stops=bus_stops)

address_to_nearest_stops = unique_addresses.set_index(['latitude', 'longitude'])[['nearest_mrt_distance', 'nearest_bus_distance']].to_dict('index')

df_resale['nearest_mrt_distance'] = df_resale.apply(lambda row: address_to_nearest_stops.get((row['latitude'], row['longitude']), {}).get('nearest_mrt_distance'), axis=1)
df_resale['nearest_bus_distance'] = df_resale.apply(lambda row: address_to_nearest_stops.get((row['latitude'], row['longitude']), {}).get('nearest_bus_distance'), axis=1)


df_resale[['nearest_mrt_distance', 'nearest_bus_distance']] = df_resale.apply(calculate_nearest_stops, axis=1, mrt_stops=MRT_stops, bus_stops=bus_stops)

# %%
df_resale
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 201055  2025-02      YISHUN  EXECUTIVE   364     YISHUN RING RD     01 TO 03
# 201056  2025-02      YISHUN  EXECUTIVE   328     YISHUN RING RD     01 TO 03
# 201057  2025-02      YISHUN  EXECUTIVE   723       YISHUN ST 71     07 TO 09
# 201058  2025-02      YISHUN  EXECUTIVE   824       YISHUN ST 81     01 TO 03
# 201059  2025-02      YISHUN  EXECUTIVE   826       YISHUN ST 81     10 TO 12
#
#         floor_area_sqm      flat_model  lease_commence_date  \
# 0                 44.0        Improved                 1979
# 1                 67.0  New Generation                 1978
# 2                 67.0  New Generation                 1980
# 3                 68.0  New Generation                 1980
# 4                 67.0  New Generation                 1980
# ...                ...             ...                  ...
# 201055           145.0      Maisonette                 1988
# 201056           142.0       Apartment                 1988
# 201057           146.0      Maisonette                 1986
# 201058           145.0       Apartment                 1987
# 201059           146.0      Maisonette                 1988
#
#            remaining_lease  resale_price                address  latitude  \
# 0       61 years 04 months      232000.0  406 ANG MO KIO AVE 10  1.362005
# 1       60 years 07 months      250000.0   108 ANG MO KIO AVE 4  1.370966
# 2       62 years 05 months      262000.0   602 ANG MO KIO AVE 5  1.380709
# 3        62 years 01 month      265000.0  465 ANG MO KIO AVE 10  1.366201
# 4       62 years 05 months      265000.0   601 ANG MO KIO AVE 5  1.381041
# ...                    ...           ...                    ...       ...
# 201055  62 years 03 months      860000.0     364 YISHUN RING RD  1.429046
# 201056  62 years 05 months      845000.0     328 YISHUN RING RD  1.429780
# 201057  60 years 05 months      818888.0       723 YISHUN ST 71  1.426020
# 201058  61 years 10 months      868888.0       824 YISHUN ST 81  1.413745
# 201059            62 years     1100888.0       826 YISHUN ST 81  1.414174
#
#          longitude  nearest_mrt_distance  nearest_bus_distance
# 0       103.853880            926.898193             97.969153
# 1       103.838202            197.441011            168.954939
# 2       103.835368            499.284921            138.097011
# 3       103.857201            880.424478             72.020174
# 4       103.835132            471.153365            123.963837
# ...            ...                   ...                   ...
# 201055  103.844622           1069.887447            145.778587
# 201056  103.843057            895.831038            241.983932
# 201057  103.829939            679.698412            167.649503
# 201058  103.833303            406.125677            153.812977
# 201059  103.832454            361.607579            137.497139
#
# [201060 rows x 16 columns]

# %%
df_resale.to_csv('../data/cleaned/resale_price_cleaned_0.csv', index=False)

# %%
geospatial_df = df_resale[['street_name', 'latitude', 'longitude', 'nearest_mrt_distance', 'nearest_bus_distance']].drop_duplicates()
geospatial_df
# Out:
#               street_name  latitude   longitude  nearest_mrt_distance  \
# 0       ANG MO KIO AVE 10  1.362005  103.853880            926.898193
# 1        ANG MO KIO AVE 4  1.370966  103.838202            197.441011
# 2        ANG MO KIO AVE 5  1.380709  103.835368            499.284921
# 3       ANG MO KIO AVE 10  1.366201  103.857201            880.424478
# 4        ANG MO KIO AVE 5  1.381041  103.835132            471.153365
# ...                   ...       ...         ...                   ...
# 199925      BUANGKOK LINK  1.385772  103.883485            476.366915
# 199926      BUANGKOK LINK  1.384839  103.883129            585.219209
# 200495    ANCHORVALE LANE  1.393436  103.884812            468.803169
# 200497    ANCHORVALE LANE  1.393907  103.884507            528.251609
# 200693  TAMPINES NTH DR 1  1.364895  103.936692           1595.466687
#
#         nearest_bus_distance
# 0                  97.969153
# 1                 168.954939
# 2                 138.097011
# 3                  72.020174
# 4                 123.963837
# ...                      ...
# 199925            166.405416
# 199926             90.385984
# 200495            213.588820
# 200497            222.585947
# 200693             99.785692
#
# [9623 rows x 5 columns]

# %%
#geospatial_df.to_csv('../data/cleaned/hdb_geospatial.csv', index=False)
