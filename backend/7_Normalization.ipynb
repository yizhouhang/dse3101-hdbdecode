# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/cleaned/resale_price_cleaned_final.csv')

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'storey_range', 'floor_area_sqm',
#        'flat_model', 'remaining_lease', 'resale_price', 'lat', 'lon',
#        'nearest_mrt_distance', 'nearest_bus_distance', 'education_score',
#        'shopping_score', 'food_score', 'recreation_score', 'healthcare_score',
#        'CPI (base 2024-12)', 'inflation_rate (x100)', 'building_age_2025',
#        'total_unemployment_rate', 'resident_unemployment_rate',
#        'interest_rate', 'fx_rate', 'avg_household_income', 'NoReligion',
#        'Buddhism', 'Taoism1', 'Islam', 'Hinduism', 'Sikhism',
#        'Christianity_Catholic', 'Christianity_OtherChristians',
#        'OtherReligions', 'Chinese', 'Malays', 'Indians', 'Others', 'year',
#        'priv_prop'],
#       dtype='object')

# %%
df_normalized_clean = df.copy()

def normalize(col):
    return (col - col.min()) / (col.max() - col.min()) if col.max() != col.min() else col

df_normalized_clean['month'] = pd.to_datetime(df_normalized_clean['month'])
df_normalized_clean['month_num'] = df_normalized_clean['month'].dt.month.astype(float)
df_normalized_clean = df_normalized_clean.drop(columns=['month'])

# %%
df_normalized_clean
# Out:
#                town  flat_type  storey_range  floor_area_sqm flat_model  \
# 0       BUKIT MERAH          3            13            59.0   Improved
# 1       BUKIT MERAH          3             7            59.0   Improved
# 2       BUKIT MERAH          3             4            59.0   Improved
# 3       BUKIT MERAH          3            10            70.0   Improved
# 4       BUKIT MERAH          3             7            65.0   Improved
# ...             ...        ...           ...             ...        ...
# 196981    SEMBAWANG          5             4           110.0   Improved
# 196982    SEMBAWANG          5             7           110.0   Improved
# 196983    SEMBAWANG          4            13            91.0    Model A
# 196984    SEMBAWANG          5            13           111.0   Improved
# 196985    SEMBAWANG          5             7           110.0   Improved
#
#         remaining_lease   resale_price       lat         lon  \
# ...

# %%
df_normalized_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196986 entries, 0 to 196985
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   town                          196986 non-null  object
#  1   flat_type                     196986 non-null  int64
#  2   storey_range                  196986 non-null  int64
#  3   floor_area_sqm                196986 non-null  float64
#  4   flat_model                    196986 non-null  object
#  5   remaining_lease               196986 non-null  float64
#  6   resale_price                  196986 non-null  float64
#  7   lat                           196986 non-null  float64
#  8   lon                           196986 non-null  float64
#  9   nearest_mrt_distance          196986 non-null  float64
#  10  nearest_bus_distance          196986 non-null  float64
#  11  education_score               196986 non-null  float64
# ...

# %%
columns_to_normalize = [
    'flat_type', 'storey_range', 'floor_area_sqm', 'remaining_lease', 'resale_price',
    'lat', 'lon', 'nearest_mrt_distance', 'nearest_bus_distance', 'education_score',
    'shopping_score', 'food_score', 'recreation_score', 'healthcare_score',
    'inflation_rate (x100)', 'building_age_2025', 'total_unemployment_rate',
    'resident_unemployment_rate', 'interest_rate', 'fx_rate', 'avg_household_income',
    'year', 'priv_prop', 'month_num', 'CPI (base 2024-12)'
]

df_normalized_clean[columns_to_normalize] = df_normalized_clean[columns_to_normalize].apply(normalize)

# %%
df_normalized_clean.to_csv('../data/cleaned/resale_price_normalized.csv', index=False)
