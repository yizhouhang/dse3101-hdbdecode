# %%
import pandas as pd
file_path = "../data/cleaned/resale_price_normalized_demo.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#      month         town  flat_type  storey_range  floor_area_sqm flat_model  \
# 0  2017-03  BUKIT MERAH   0.333333        0.2500        0.083408   Improved
# 1  2017-05  BUKIT MERAH   0.333333        0.1250        0.083408   Improved
# 2  2017-03  BUKIT MERAH   0.333333        0.0625        0.083408   Improved
# 3  2017-12  BUKIT MERAH   0.333333        0.1875        0.116175   Improved
# 4  2017-01  BUKIT MERAH   0.333333        0.1250        0.101281   Improved
#
#    remaining_lease  resale_price       lat       lon  ...     Islam  Hinduism  \
# 0         0.312121      0.131278  0.000000  0.456109  ...  0.085283  0.038491
# 1         0.309346      0.131197  0.000000  0.456109  ...  0.085283  0.038491
# 2         0.312121      0.127206  0.002888  0.454289  ...  0.085283  0.038491
# 3         0.299116      0.171393  0.002888  0.454289  ...  0.085283  0.038491
# 4         0.310733      0.190853  0.005513  0.415298  ...  0.085283  0.038491
#
#     Sikhism  Christianity_Catholic  Christianity_OtherChristians  \
# 0  0.006792               0.062642                      0.123019
# 1  0.006792               0.062642                      0.123019
# 2  0.006792               0.062642                      0.123019
# 3  0.006792               0.062642                      0.123019
# 4  0.006792               0.062642                      0.123019
#
#    OtherReligions   Chinese    Malays   Indians    Others
# 0        0.003774  0.786768  0.085986  0.097023  0.030223
# 1        0.003774  0.786768  0.085986  0.097023  0.030223
# 2        0.003774  0.786768  0.085986  0.097023  0.030223
# 3        0.003774  0.786768  0.085986  0.097023  0.030223
# 4        0.003774  0.786768  0.085986  0.097023  0.030223
#
# [5 rows x 38 columns]

# %%
df['month'] = pd.to_datetime(df['month'], format='%Y-%m')
df['year'] = df['month'].dt.year
df['month'] = df['month'].dt.month

# Reorganize columns
columns_order = ['resale_price','year', 'month', 'flat_type', 'floor_area_sqm', 'storey_range'] + [col for col in df.columns if col not in ['resale_price','year', 'month', 'flat_type', 'floor_area_sqm', 'storey_range', 'flat_model','building_age_2025','Chinese','NoReligion']]
df = df[columns_order]
df.head()
# Out:
#    resale_price  year  month  flat_type  floor_area_sqm  storey_range  \
# 0      0.131278  2017      3   0.333333        0.083408        0.2500
# 1      0.131197  2017      5   0.333333        0.083408        0.1250
# 2      0.127206  2017      3   0.333333        0.083408        0.0625
# 3      0.171393  2017     12   0.333333        0.116175        0.1875
# 4      0.190853  2017      1   0.333333        0.101281        0.1250
#
#           town  remaining_lease       lat       lon  ...   Taoism1     Islam  \
# 0  BUKIT MERAH         0.312121  0.000000  0.456109  ...  0.099623  0.085283
# 1  BUKIT MERAH         0.309346  0.000000  0.456109  ...  0.099623  0.085283
# 2  BUKIT MERAH         0.312121  0.002888  0.454289  ...  0.099623  0.085283
# 3  BUKIT MERAH         0.299116  0.002888  0.454289  ...  0.099623  0.085283
# 4  BUKIT MERAH         0.310733  0.005513  0.415298  ...  0.099623  0.085283
#
#    Hinduism   Sikhism  Christianity_Catholic  Christianity_OtherChristians  \
# 0  0.038491  0.006792               0.062642                      0.123019
# 1  0.038491  0.006792               0.062642                      0.123019
# 2  0.038491  0.006792               0.062642                      0.123019
# 3  0.038491  0.006792               0.062642                      0.123019
# 4  0.038491  0.006792               0.062642                      0.123019
#
#    OtherReligions    Malays   Indians    Others
# 0        0.003774  0.085986  0.097023  0.030223
# 1        0.003774  0.085986  0.097023  0.030223
# 2        0.003774  0.085986  0.097023  0.030223
# 3        0.003774  0.085986  0.097023  0.030223
# 4        0.003774  0.085986  0.097023  0.030223
#
# [5 rows x 35 columns]

# %%
df = pd.get_dummies(df, columns=['town'], prefix='town', drop_first=True)
df = df.dropna()
df.head()
# Out:
#    resale_price  year  month  flat_type  floor_area_sqm  storey_range  \
# 0      0.131278  2017      3   0.333333        0.083408        0.2500
# 1      0.131197  2017      5   0.333333        0.083408        0.1250
# 2      0.127206  2017      3   0.333333        0.083408        0.0625
# 3      0.171393  2017     12   0.333333        0.116175        0.1875
# 4      0.190853  2017      1   0.333333        0.101281        0.1250
#
#    remaining_lease       lat       lon  nearest_mrt_distance  ...  \
# 0         0.312121  0.000000  0.456109              0.159033  ...
# 1         0.309346  0.000000  0.456109              0.159033  ...
# 2         0.312121  0.002888  0.454289              0.170487  ...
# 3         0.299116  0.002888  0.454289              0.170487  ...
# 4         0.310733  0.005513  0.415298              0.035276  ...
#
#    town_PASIR RIS  town_PUNGGOL  town_QUEENSTOWN  town_SEMBAWANG  \
# 0           False         False            False           False
# 1           False         False            False           False
# 2           False         False            False           False
# 3           False         False            False           False
# 4           False         False            False           False
#
#    town_SENGKANG  town_SERANGOON  town_TAMPINES  town_TOA PAYOH  \
# 0          False           False          False           False
# 1          False           False          False           False
# 2          False           False          False           False
# 3          False           False          False           False
# 4          False           False          False           False
#
#    town_WOODLANDS  town_YISHUN
# 0           False        False
# 1           False        False
# 2           False        False
# 3           False        False
# 4           False        False
#
# [5 rows x 59 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
correlation_matrix
# Out:
#                               resale_price          year     month  flat_type  \
# resale_price                      1.000000  1.913384e-01  0.014628   0.623289
# year                              0.191338  1.000000e+00 -0.049294  -0.035020
# month                             0.014628 -4.929359e-02  1.000000   0.002730
# flat_type                         0.623289 -3.501986e-02  0.002730   1.000000
# floor_area_sqm                    0.629457 -3.854288e-02  0.000389   0.936853
# storey_range                      0.366034  1.146718e-02 -0.002756   0.006655
# remaining_lease                   0.337871 -2.612902e-02 -0.002745   0.139723
# lat                              -0.194975  2.106145e-02  0.005145   0.156838
# lon                               0.102951  3.133154e-03  0.005005  -0.004317
# nearest_mrt_distance             -0.095566  1.628942e-02 -0.001075  -0.000428
# nearest_bus_distance              0.033790  6.265793e-03  0.001394   0.010258
# education_score                  -0.030096 -3.404493e-02  0.003565   0.126682
# shopping_score                    0.175823  1.113277e-02  0.006272  -0.098731
# food_score                        0.124841 -2.657665e-02 -0.000161  -0.255017
# recreation_score                  0.100140 -5.508202e-02 -0.002227  -0.122445
# healthcare_score                  0.189385 -2.061890e-02  0.003589  -0.071760
# CPI (base 2024-12)                0.180383  9.076747e-01  0.056520  -0.044314
# inflation_rate (x100)             0.056314  2.222852e-01  0.084847  -0.003456
# total_unemployment_rate          -0.086999 -3.646639e-01  0.058581   0.033740
# resident_unemployment_rate       -0.068182 -2.971982e-01  0.054696   0.034962
# interest_rate                     0.096496  6.257579e-01  0.045398  -0.045523
# fx_rate                          -0.082521 -3.521548e-01  0.100932   0.001706
# avg_household_income             -0.098954 -6.973418e-01  0.016298  -0.013620
# Buddhism                         -0.137768 -1.201468e-01  0.005666  -0.039406
# Taoism1                          -0.160415 -1.497285e-01 -0.000480  -0.051635
# Islam                            -0.150315  6.449252e-02  0.001438   0.140965
# Hinduism                         -0.161300 -9.517374e-04  0.000393   0.037390
# Sikhism                           0.070144  1.186269e-02  0.001184  -0.062227
# Christianity_Catholic             0.188806  1.346241e-02 -0.003056  -0.077204
# Christianity_OtherChristians      0.253527 -2.241767e-02 -0.003771  -0.086563
# OtherReligions                    0.133753  5.788056e-02  0.001060  -0.009778
# Malays                           -0.066740 -4.970841e-15  0.002244   0.046400
# Indians                          -0.058837  1.649765e-14 -0.003049   0.004439
# Others                            0.043540  1.955252e-14 -0.003028  -0.007524
# town_BEDOK                       -0.057363 -9.235430e-03 -0.003809  -0.063824
# town_BISHAN                       0.151947 -1.651631e-02 -0.000368   0.039322
# town_BUKIT BATOK                 -0.042476  3.576738e-02 -0.004129  -0.025602
# town_BUKIT MERAH                  0.134261 -4.999892e-03 -0.000325  -0.077006
# town_BUKIT PANJANG               -0.021957 -1.283742e-02  0.000827   0.045280
# town_BUKIT TIMAH                  0.074626 -5.867014e-03 -0.002701   0.021725
# town_CENTRAL AREA                 0.090145 -6.125365e-03 -0.003879  -0.043599
# town_CHOA CHU KANG               -0.046024  1.222937e-02 -0.003085   0.073052
# town_CLEMENTI                     0.027085 -2.680713e-03 -0.008195  -0.061917
# town_GEYLANG                     -0.014823 -2.543446e-04  0.003078  -0.067865
# town_HOUGANG                     -0.006421  1.028132e-02 -0.002842   0.024209
# town_JURONG EAST                 -0.037903 -9.575439e-03 -0.000044  -0.004893
# town_JURONG WEST                 -0.092342 -1.844698e-02 -0.001357   0.054293
# town_KALLANG/WHAMPOA              0.065728  6.001303e-03  0.001886  -0.068515
# town_MARINE PARADE                0.019561 -1.955770e-03  0.003043  -0.030915
# town_PASIR RIS                    0.062939 -9.952355e-03 -0.002310   0.136683
# town_PUNGGOL                      0.030347  1.908841e-02  0.002721   0.006103
# town_QUEENSTOWN                   0.115303 -3.574139e-03 -0.000006  -0.080014
# town_SEMBAWANG                   -0.041691  2.352099e-02  0.005140   0.044135
# town_SENGKANG                     0.002718  7.975056e-04  0.006965   0.062237
# town_SERANGOON                    0.033786 -1.445603e-02 -0.001556   0.027819
# town_TAMPINES                     0.047959  5.104049e-03  0.004134   0.041202
# town_TOA PAYOH                    0.033415 -1.182245e-02  0.002353  -0.071425
# town_WOODLANDS                   -0.080416 -2.232816e-03  0.003651   0.073789
# town_YISHUN                      -0.118738  5.423725e-03 -0.003445  -0.045602
#
#                               floor_area_sqm  storey_range  remaining_lease  \
# resale_price                        0.629457      0.366034         0.337871
# year                               -0.038543      0.011467        -0.026129
# month                               0.000389     -0.002756        -0.002745
# flat_type                           0.936853      0.006655         0.139723
# floor_area_sqm                      1.000000     -0.013874         0.116049
# storey_range                       -0.013874      1.000000         0.274582
# remaining_lease                     0.116049      0.274582         1.000000
# lat                                 0.164745     -0.138523         0.346403
# lon                                -0.006835     -0.048533         0.000109
# nearest_mrt_distance                0.026500     -0.075018        -0.115080
# nearest_bus_distance                0.012486      0.005407        -0.046432
# education_score                     0.134671     -0.086867         0.092825
# shopping_score                     -0.123848      0.122520         0.010809
# food_score                         -0.287113      0.147066        -0.342296
# recreation_score                   -0.142336      0.065749        -0.344043
# healthcare_score                   -0.113035      0.121966        -0.008777
# CPI (base 2024-12)                 -0.045365      0.006416        -0.037917
# inflation_rate (x100)              -0.005043      0.009991        -0.004716
# total_unemployment_rate             0.029580     -0.002182         0.039454
# resident_unemployment_rate          0.030070      0.000003         0.038892
# interest_rate                      -0.043406     -0.002748        -0.038460
# fx_rate                             0.003125     -0.010301         0.010422
# avg_household_income               -0.007516      0.008847        -0.034323
# Buddhism                           -0.082661      0.049482         0.224708
# Taoism1                            -0.053740     -0.006040        -0.065339
# Islam                               0.183694     -0.156729         0.100550
# Hinduism                            0.045776     -0.040306         0.049038
# Sikhism                            -0.070516      0.042496        -0.121467
# Christianity_Catholic              -0.084263      0.052401        -0.192584
# Christianity_OtherChristians       -0.092203      0.101257        -0.219012
# OtherReligions                     -0.016337      0.064775        -0.065706
# Malays                              0.063034     -0.043000         0.025361
# Indians                             0.011305     -0.027141        -0.020295
# Others                             -0.010125     -0.003829        -0.056752
# town_BEDOK                         -0.069338     -0.042910        -0.179687
# town_BISHAN                         0.060663     -0.006107        -0.058999
# town_BUKIT BATOK                   -0.022267     -0.004356        -0.007968
# town_BUKIT MERAH                   -0.081872      0.098277        -0.052940
# town_BUKIT PANJANG                  0.041400      0.038299         0.069106
# town_BUKIT TIMAH                    0.025179     -0.011922        -0.045049
# town_CENTRAL AREA                  -0.057260      0.112360        -0.036311
# town_CHOA CHU KANG                  0.101602     -0.017952         0.071300
# town_CLEMENTI                      -0.066549      0.045826        -0.069517
# town_GEYLANG                       -0.088394     -0.028168        -0.124346
# town_HOUGANG                        0.031266     -0.043213        -0.016976
# town_JURONG EAST                    0.002580      0.006826        -0.063018
# town_JURONG WEST                    0.051895     -0.034504        -0.005674
# town_KALLANG/WHAMPOA               -0.076789      0.060075        -0.077257
# town_MARINE PARADE                 -0.034725      0.008671        -0.117403
# town_PASIR RIS                      0.166536     -0.055264        -0.005703
# town_PUNGGOL                       -0.016262      0.036211         0.316694
# town_QUEENSTOWN                    -0.101367      0.144453        -0.035888
# town_SEMBAWANG                      0.017139     -0.008148         0.126094
# town_SENGKANG                       0.028904      0.071947         0.258798
# town_SERANGOON                      0.025383     -0.047788        -0.076921
# town_TAMPINES                       0.081267     -0.092340        -0.060578
# town_TOA PAYOH                     -0.079847      0.061163        -0.123223
# town_WOODLANDS                      0.100879     -0.066978         0.048605
# town_YISHUN                        -0.046945     -0.084278         0.005646
#
#                                    lat       lon  nearest_mrt_distance  ...  \
# resale_price                 -0.194975  0.102951             -0.095566  ...
# year                          0.021061  0.003133              0.016289  ...
# month                         0.005145  0.005005             -0.001075  ...
# flat_type                     0.156838 -0.004317             -0.000428  ...
# floor_area_sqm                0.164745 -0.006835              0.026500  ...
# storey_range                 -0.138523 -0.048533             -0.075018  ...
# remaining_lease               0.346403  0.000109             -0.115080  ...
# lat                           1.000000  0.005935             -0.057352  ...
# lon                           0.005935  1.000000             -0.076732  ...
# nearest_mrt_distance         -0.057352 -0.076732              1.000000  ...
# nearest_bus_distance         -0.060477  0.085652             -0.004995  ...
# education_score               0.341172  0.327826             -0.189452  ...
# shopping_score               -0.253829  0.247459             -0.261130  ...
# food_score                   -0.665217  0.072817             -0.063796  ...
# recreation_score             -0.421466  0.157310             -0.100652  ...
# healthcare_score             -0.430107  0.296494             -0.236820  ...
# CPI (base 2024-12)            0.023745 -0.013255              0.023025  ...
# inflation_rate (x100)         0.000234  0.011899             -0.005014  ...
# total_unemployment_rate      -0.014817  0.034598             -0.016851  ...
# resident_unemployment_rate   -0.015523  0.037435             -0.017800  ...
# interest_rate                 0.030031 -0.031429              0.026765  ...
# fx_rate                       0.005677 -0.003665              0.003378  ...
# avg_household_income         -0.200390 -0.033125              0.013119  ...
# Buddhism                      0.229579 -0.158118             -0.237859  ...
# Taoism1                      -0.045221 -0.450149              0.004946  ...
# Islam                         0.405398 -0.076820              0.082628  ...
# Hinduism                      0.327120 -0.587949              0.212531  ...
# Sikhism                      -0.285076  0.144858              0.174649  ...
# Christianity_Catholic        -0.285998  0.519472              0.045038  ...
# Christianity_OtherChristians -0.513448  0.274101              0.049555  ...
# OtherReligions               -0.289332  0.046410              0.198731  ...
# Malays                        0.128558 -0.045126              0.012298  ...
# Indians                       0.066949 -0.159176              0.091502  ...
# Others                       -0.088018  0.089108              0.043962  ...
# town_BEDOK                   -0.211255  0.287446             -0.003162  ...
# town_BISHAN                  -0.047220  0.008965              0.019594  ...
# town_BUKIT BATOK             -0.073457 -0.265990              0.062101  ...
# town_BUKIT MERAH             -0.403534 -0.055721             -0.001218  ...
# town_BUKIT PANJANG            0.068768 -0.202416             -0.173587  ...
# town_BUKIT TIMAH             -0.042591 -0.038348             -0.036945  ...
# town_CENTRAL AREA            -0.164952  0.006464             -0.063730  ...
# town_CHOA CHU KANG            0.088223 -0.294315             -0.051005  ...
# town_CLEMENTI                -0.191583 -0.159416              0.036569  ...
# town_GEYLANG                 -0.173487  0.111176             -0.080112  ...
# town_HOUGANG                  0.018803  0.153767              0.129311  ...
# town_JURONG EAST             -0.104983 -0.207434              0.101538  ...
# town_JURONG WEST             -0.153262 -0.499324              0.148998  ...
# town_KALLANG/WHAMPOA         -0.201939  0.049862             -0.055935  ...
# town_MARINE PARADE           -0.117355  0.078743              0.261871  ...
# town_PASIR RIS                0.015956  0.267140              0.189839  ...
# town_PUNGGOL                  0.223881  0.257482             -0.267766  ...
# town_QUEENSTOWN              -0.258483 -0.103120             -0.059990  ...
# town_SEMBAWANG                0.324382 -0.048060             -0.021954  ...
# town_SENGKANG                 0.159736  0.211295             -0.270584  ...
# town_SERANGOON               -0.023320  0.058474              0.160915  ...
# town_TAMPINES                -0.092576  0.395678              0.033178  ...
# town_TOA PAYOH               -0.132982  0.030466             -0.007108  ...
# town_WOODLANDS                0.453707 -0.193729              0.013006  ...
# town_YISHUN                   0.366322 -0.008085              0.196031  ...
#
#                               town_PASIR RIS  town_PUNGGOL  town_QUEENSTOWN  \
# resale_price                        0.062939      0.030347         0.115303
# year                               -0.009952      0.019088        -0.003574
# month                              -0.002310      0.002721        -0.000006
# flat_type                           0.136683      0.006103        -0.080014
# floor_area_sqm                      0.166536     -0.016262        -0.101367
# storey_range                       -0.055264      0.036211         0.144453
# remaining_lease                    -0.005703      0.316694        -0.035888
# lat                                 0.015956      0.223881        -0.258483
# lon                                 0.267140      0.257482        -0.103120
# nearest_mrt_distance                0.189839     -0.267766        -0.059990
# nearest_bus_distance               -0.006056      0.051343         0.025902
# education_score                    -0.022640      0.178726        -0.218366
# shopping_score                     -0.109624      0.068639         0.006584
# food_score                         -0.137230     -0.181643         0.229094
# recreation_score                   -0.123484     -0.273368        -0.063506
# healthcare_score                   -0.077488      0.134391         0.009657
# CPI (base 2024-12)                 -0.016158      0.009198        -0.009224
# inflation_rate (x100)               0.000148      0.010085         0.003299
# total_unemployment_rate             0.019799      0.008837         0.010711
# resident_unemployment_rate          0.020316      0.011795         0.012329
# interest_rate                      -0.020914     -0.006491        -0.012931
# fx_rate                             0.007663     -0.023132        -0.003642
# avg_household_income               -0.064369      0.099282         0.099515
# Buddhism                           -0.391885      0.182828        -0.186683
# Taoism1                            -0.279165     -0.211035        -0.187773
# Islam                               0.188460     -0.062190        -0.212135
# Hinduism                           -0.225548     -0.306079        -0.086725
# Sikhism                             0.052881     -0.167342         0.289930
# Christianity_Catholic               0.097898      0.022768         0.163850
# Christianity_OtherChristians        0.173602     -0.001842         0.385867
# OtherReligions                      0.238412      0.082870         0.011723
# Malays                              0.066661     -0.015152        -0.050573
# Indians                            -0.020688     -0.130021        -0.033934
# Others                              0.099742     -0.057949         0.086378
# town_BEDOK                         -0.040877     -0.066684        -0.039549
# town_BISHAN                        -0.023387     -0.038152        -0.022627
# town_BUKIT BATOK                   -0.035515     -0.057937        -0.034361
# town_BUKIT MERAH                   -0.034620     -0.056477        -0.033495
# town_BUKIT PANJANG                 -0.033709     -0.054992        -0.032614
# town_BUKIT TIMAH                   -0.008649     -0.014110        -0.008368
# town_CENTRAL AREA                  -0.015531     -0.025337        -0.015027
# town_CHOA CHU KANG                 -0.037968     -0.061940        -0.036735
# town_CLEMENTI                      -0.026194     -0.042731        -0.025343
# town_GEYLANG                       -0.027577     -0.044988        -0.026681
# town_HOUGANG                       -0.039945     -0.065165        -0.038648
# town_JURONG EAST                   -0.025085     -0.040923        -0.024270
# town_JURONG WEST                   -0.046249     -0.075449        -0.044747
# town_KALLANG/WHAMPOA               -0.030762     -0.050183        -0.029763
# town_MARINE PARADE                 -0.013616     -0.022212        -0.013174
# town_PASIR RIS                      1.000000     -0.049139        -0.029143
# town_PUNGGOL                       -0.049139      1.000000        -0.047543
# town_QUEENSTOWN                    -0.029143     -0.047543         1.000000
# town_SEMBAWANG                     -0.029488     -0.048105        -0.028530
# town_SENGKANG                      -0.052041     -0.084897        -0.050350
# town_SERANGOON                     -0.023518     -0.038367        -0.022755
# town_TAMPINES                      -0.046565     -0.075964        -0.045053
# town_TOA PAYOH                     -0.031143     -0.050806        -0.030132
# town_WOODLANDS                     -0.048004     -0.078311        -0.046445
# town_YISHUN                        -0.046951     -0.076593        -0.045426
#
#                               town_SEMBAWANG  town_SENGKANG  town_SERANGOON  \
# resale_price                       -0.041691       0.002718        0.033786
# year                                0.023521       0.000798       -0.014456
# month                               0.005140       0.006965       -0.001556
# flat_type                           0.044135       0.062237        0.027819
# floor_area_sqm                      0.017139       0.028904        0.025383
# storey_range                       -0.008148       0.071947       -0.047788
# remaining_lease                     0.126094       0.258798       -0.076921
# lat                                 0.324382       0.159736       -0.023320
# lon                                -0.048060       0.211295        0.058474
# nearest_mrt_distance               -0.021954      -0.270584        0.160915
# nearest_bus_distance               -0.034268       0.017749       -0.011841
# education_score                    -0.090316       0.333121        0.066369
# shopping_score                     -0.048559       0.041369       -0.008416
# food_score                         -0.115825      -0.115592       -0.000660
# recreation_score                   -0.084526       0.057852        0.265497
# healthcare_score                   -0.183662       0.364028        0.065087
# CPI (base 2024-12)                  0.035944      -0.009409       -0.012733
# inflation_rate (x100)               0.001248       0.004119       -0.006412
# total_unemployment_rate            -0.037675       0.021677        0.003504
# resident_unemployment_rate         -0.038746       0.023444        0.002442
# interest_rate                       0.042097      -0.017982       -0.008629
# fx_rate                            -0.002594       0.002116        0.000064
# avg_household_income               -0.040790      -0.215228        0.107550
# Buddhism                            0.096285       0.369141       -0.138500
# Taoism1                            -0.066405      -0.083719        0.025045
# Islam                               0.025049      -0.179131       -0.243097
# Hinduism                            0.046965       0.089652        0.135276
# Sikhism                            -0.058216      -0.084078        0.008467
# Christianity_Catholic              -0.103800       0.041148        0.327632
# Christianity_OtherChristians       -0.061276      -0.131276        0.251012
# OtherReligions                      0.025626      -0.125197        0.021320
# Malays                             -0.006869      -0.054050       -0.094473
# Indians                             0.020292      -0.009325       -0.001232
# Others                              0.109727      -0.046100       -0.013232
# town_BEDOK                         -0.040017      -0.070623       -0.031916
# town_BISHAN                        -0.022895      -0.040405       -0.018260
# town_BUKIT BATOK                   -0.034768      -0.061358       -0.027729
# town_BUKIT MERAH                   -0.033891      -0.059812       -0.027030
# town_BUKIT PANJANG                 -0.033000      -0.058239       -0.026320
# town_BUKIT TIMAH                   -0.008467      -0.014943       -0.006753
# town_CENTRAL AREA                  -0.015205      -0.026833       -0.012127
# town_CHOA CHU KANG                 -0.037170      -0.065597       -0.029645
# town_CLEMENTI                      -0.025643      -0.045254       -0.020452
# town_GEYLANG                       -0.026997      -0.047645       -0.021532
# town_HOUGANG                       -0.039105      -0.069013       -0.031189
# town_JURONG EAST                   -0.024558      -0.043339       -0.019586
# town_JURONG WEST                   -0.045277      -0.079905       -0.036111
# town_KALLANG/WHAMPOA               -0.030115      -0.053147       -0.024018
# town_MARINE PARADE                 -0.013330      -0.023524       -0.010631
# town_PASIR RIS                     -0.029488      -0.052041       -0.023518
# town_PUNGGOL                       -0.048105      -0.084897       -0.038367
# town_QUEENSTOWN                    -0.028530      -0.050350       -0.022755
# town_SEMBAWANG                      1.000000      -0.050946       -0.023024
# town_SENGKANG                      -0.050946       1.000000       -0.040633
# town_SERANGOON                     -0.023024      -0.040633        1.000000
# town_TAMPINES                      -0.045586      -0.080450       -0.036358
# town_TOA PAYOH                     -0.030488      -0.053806       -0.024316
# town_WOODLANDS                     -0.046994      -0.082936       -0.037481
# town_YISHUN                        -0.045963      -0.081117       -0.036659
#
#                               town_TAMPINES  town_TOA PAYOH  town_WOODLANDS  \
# resale_price                       0.047959        0.033415       -0.080416
# year                               0.005104       -0.011822       -0.002233
# month                              0.004134        0.002353        0.003651
# flat_type                          0.041202       -0.071425        0.073789
# floor_area_sqm                     0.081267       -0.079847        0.100879
# storey_range                      -0.092340        0.061163       -0.066978
# remaining_lease                   -0.060578       -0.123223        0.048605
# lat                               -0.092576       -0.132982        0.453707
# lon                                0.395678        0.030466       -0.193729
# nearest_mrt_distance               0.033178       -0.007108        0.013006
# nearest_bus_distance              -0.026432       -0.012581       -0.048078
# education_score                    0.218098        0.090398        0.022938
# shopping_score                     0.080015        0.029514       -0.011632
# food_score                        -0.141556        0.231332       -0.165150
# recreation_score                  -0.040810        0.151754       -0.277092
# healthcare_score                  -0.167029        0.105376       -0.341393
# CPI (base 2024-12)                -0.000018       -0.008864        0.009878
# inflation_rate (x100)             -0.000053        0.000613       -0.002798
# total_unemployment_rate            0.011702       -0.000547       -0.024631
# resident_unemployment_rate         0.012800       -0.000789       -0.027037
# interest_rate                     -0.006735       -0.007198        0.026012
# fx_rate                           -0.003902        0.000780        0.006760
# avg_household_income               0.108499        0.060216       -0.252109
# Buddhism                          -0.305262        0.090778       -0.065126
# Taoism1                           -0.185085       -0.009838       -0.260022
# Islam                              0.412966       -0.242357        0.501749
# Hinduism                          -0.317816       -0.192365        0.364087
# Sikhism                            0.018472       -0.159865       -0.011332
# Christianity_Catholic             -0.084524        0.275010       -0.309966
# Christianity_OtherChristians      -0.010335        0.145709       -0.341943
# OtherReligions                    -0.149307        0.142189        0.041031
# Malays                             0.110296       -0.079613        0.187200
# Indians                           -0.047896       -0.087930        0.177852
# Others                             0.028088       -0.010780       -0.052147
# town_BEDOK                        -0.063192       -0.042263       -0.065144
# town_BISHAN                       -0.036154       -0.024180       -0.037271
# town_BUKIT BATOK                  -0.054903       -0.036719       -0.056599
# town_BUKIT MERAH                  -0.053519       -0.035794       -0.055172
# town_BUKIT PANJANG                -0.052112       -0.034853       -0.053722
# town_BUKIT TIMAH                  -0.013371       -0.008942       -0.013784
# town_CENTRAL AREA                 -0.024010       -0.016058       -0.024752
# town_CHOA CHU KANG                -0.058696       -0.039256       -0.060509
# town_CLEMENTI                     -0.040493       -0.027082       -0.041744
# town_GEYLANG                      -0.042632       -0.028513       -0.043949
# town_HOUGANG                      -0.061752       -0.041300       -0.063660
# town_JURONG EAST                  -0.038780       -0.025936       -0.039978
# town_JURONG WEST                  -0.071498       -0.047818       -0.073707
# town_KALLANG/WHAMPOA              -0.047555       -0.031805       -0.049025
# town_MARINE PARADE                -0.021049       -0.014078       -0.021699
# town_PASIR RIS                    -0.046565       -0.031143       -0.048004
# town_PUNGGOL                      -0.075964       -0.050806       -0.078311
# town_QUEENSTOWN                   -0.045053       -0.030132       -0.046445
# town_SEMBAWANG                    -0.045586       -0.030488       -0.046994
# town_SENGKANG                     -0.080450       -0.053806       -0.082936
# town_SERANGOON                    -0.036358       -0.024316       -0.037481
# town_TAMPINES                      1.000000       -0.048145       -0.074210
# town_TOA PAYOH                    -0.048145        1.000000       -0.049632
# town_WOODLANDS                    -0.074210       -0.049632        1.000000
# town_YISHUN                       -0.072582       -0.048543       -0.074825
#
#                               town_YISHUN
# resale_price                    -0.118738
# year                             0.005424
# month                           -0.003445
# flat_type                       -0.045602
# floor_area_sqm                  -0.046945
# storey_range                    -0.084278
# remaining_lease                  0.005646
# lat                              0.366322
# lon                             -0.008085
# nearest_mrt_distance             0.196031
# nearest_bus_distance            -0.011382
# education_score                 -0.005066
# shopping_score                  -0.144256
# food_score                      -0.175334
# recreation_score                -0.161107
# healthcare_score                -0.317618
# CPI (base 2024-12)               0.003788
# inflation_rate (x100)           -0.000100
# total_unemployment_rate         -0.000309
# resident_unemployment_rate      -0.000908
# interest_rate                    0.009074
# fx_rate                          0.017779
# avg_household_income            -0.076553
# Buddhism                         0.113582
# Taoism1                          0.100131
# Islam                            0.158592
# Hinduism                         0.326867
# Sikhism                          0.106675
# Christianity_Catholic           -0.164998
# Christianity_OtherChristians    -0.247631
# OtherReligions                  -0.230413
# Malays                           0.037937
# Indians                          0.074192
# Others                          -0.022201
# town_BEDOK                      -0.063715
# town_BISHAN                     -0.036453
# town_BUKIT BATOK                -0.055357
# town_BUKIT MERAH                -0.053962
# town_BUKIT PANJANG              -0.052543
# town_BUKIT TIMAH                -0.013481
# town_CENTRAL AREA               -0.024209
# town_CHOA CHU KANG              -0.059182
# town_CLEMENTI                   -0.040828
# town_GEYLANG                    -0.042985
# town_HOUGANG                    -0.062264
# town_JURONG EAST                -0.039101
# town_JURONG WEST                -0.072090
# town_KALLANG/WHAMPOA            -0.047949
# town_MARINE PARADE              -0.021223
# town_PASIR RIS                  -0.046951
# town_PUNGGOL                    -0.076593
# town_QUEENSTOWN                 -0.045426
# town_SEMBAWANG                  -0.045963
# town_SENGKANG                   -0.081117
# town_SERANGOON                  -0.036659
# town_TAMPINES                   -0.072582
# town_TOA PAYOH                  -0.048543
# town_WOODLANDS                  -0.074825
# town_YISHUN                      1.000000
#
# [59 rows x 59 columns]

# %%
correlation_matrix = df.select_dtypes(include=['number']).corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt='.2f', linewidths=0.4)
plt.title('Correlation Heatmap')
plt.show()

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# from patsy import dmatrices

# numeric_columns = df.select_dtypes(include=['number']).columns
# numeric_columns = numeric_columns.drop('resale_price')

# vif_data = pd.DataFrame()
# vif_data['Feature'] = numeric_columns
# vif_data['VIF'] = [variance_inflation_factor(df[numeric_columns].values, i) for i in range(len(numeric_columns))]

# print(vif_data)
